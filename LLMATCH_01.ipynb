# %% [markdown]
# <a href="https://colab.research.google.com/github/rui1011/LLMATCH_RuiKomatsu/blob/main/LLMATCH_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install llama-index --upgrade
# !pip install llama-index
# !pip install llama-index-core
# !pip install llama-index-embeddings-huggingface
# !pip install torch
# !pip install langchain-community
# !pip install --upgrade llama-index
# !pip install --upgrade llama-index python-dotenv pydantic PyYAML
# !pip install llama-index-llms-huggingface
# !pip install --upgrade llama-index-llms-huggingface

# !pip uninstall -y llama-index-agent-openai llama-index-embeddings-openai \
               llama-index-llms-openai llama-index-multi-modal-llms-openai \
               llama-index-program-openai llama-index-question-gen-openai

# !pip install llama-index-llms-langchain
# !pip install langchain_community pypdf
# !pip install -U bitsandbytes
# !pip install -U "transformers>=4.48.0" sentence-transformers
# !pip install llama-index-embeddings-huggingface
# !pip install --upgrade bitsandbytes
# !pip install --upgrade transformers
# !pip install autoawq
# !pip install -q -U google-generativeai
# !pip install pdf2image
# !pip install pillow
# !sudo apt-get install poppler-utils -y
# !pip install git+https://github.com/huggingface/transformers
# !pip install decord
# !pip install -U sentence-transformers
# Out:
# Collecting llama-index
#   Downloading llama_index-0.12.41-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-agent-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.9-py3-none-any.whl.metadata (438 bytes)
# Collecting llama-index-cli<0.5,>=0.4.2 (from llama-index)
#   Downloading llama_index_cli-0.4.3-py3-none-any.whl.metadata (1.4 kB)
# Collecting llama-index-core<0.13,>=0.12.41 (from llama-index)
#   Downloading llama_index_core-0.12.41-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.7.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-llms-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.4.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting llama-index-multi-modal-llms-openai<0.6,>=0.5.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.5.1-py3-none-any.whl.metadata (440 bytes)
# Collecting llama-index-program-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.2-py3-none-any.whl.metadata (473 bytes)
# Collecting llama-index-question-gen-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.1-py3-none-any.whl.metadata (492 bytes)
# Collecting llama-index-readers-file<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.84.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (3.11.15)
# Collecting aiosqlite (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting banks<3,>=2.0.0 (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading banks-2.1.2-py3-none-any.whl.metadata (12 kB)
# Collecting dataclasses-json (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting dirtyjson<2,>=1.0.8 (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2,>=1.2.0 (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.41->llama-index) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (4.14.0)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.17.2)
# Collecting llama-cloud==0.1.23 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.23-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from llama-cloud==0.1.23->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.4.26)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pandas<2.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.2)
# Collecting pypdf<6,>=5.1.0 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.6.30-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.20.0)
# Collecting griffe (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading griffe-1.7.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.41->llama-index) (0.16.0)
# Collecting llama-cloud-services>=0.6.30 (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_cloud_services-0.6.30-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.41->llama-index) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.41->llama-index) (3.2.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from llama-cloud-services>=0.6.30->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.41->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Collecting colorama>=0.4 (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.0.2)
# Downloading llama_index-0.12.41-py3-none-any.whl (7.1 kB)
# Downloading llama_index_agent_openai-0.4.9-py3-none-any.whl (14 kB)
# Downloading llama_index_cli-0.4.3-py3-none-any.whl (28 kB)
# Downloading llama_index_core-0.12.41-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 66.4 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.7.4-py3-none-any.whl (15 kB)
# Downloading llama_cloud-0.1.23-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.3/267.3 kB 20.1 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.4.4-py3-none-any.whl (25 kB)
# Downloading llama_index_multi_modal_llms_openai-0.5.1-py3-none-any.whl (3.4 kB)
# Downloading llama_index_program_openai-0.3.2-py3-none-any.whl (6.1 kB)
# Downloading llama_index_question_gen_openai-0.3.1-py3-none-any.whl (3.7 kB)
# Downloading llama_index_readers_file-0.4.9-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.4 MB/s eta 0:00:00
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading banks-2.1.2-py3-none-any.whl (28 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading llama_parse-0.6.30-py3-none-any.whl (4.9 kB)
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 23.1 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading llama_cloud_services-0.6.30-py3-none-any.whl (38 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.3 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading griffe-1.7.3-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 12.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: striprtf, filetype, dirtyjson, python-dotenv, pypdf, mypy-extensions, marshmallow, deprecated, colorama, aiosqlite, typing-inspect, griffe, llama-cloud, dataclasses-json, banks, llama-index-core, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-cloud-services, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed aiosqlite-0.21.0 banks-2.1.2 colorama-0.4.6 dataclasses-json-0.6.7 deprecated-1.2.18 dirtyjson-1.0.8 filetype-1.2.0 griffe-1.7.3 llama-cloud-0.1.23 llama-cloud-services-0.6.30 llama-index-0.12.41 llama-index-agent-openai-0.4.9 llama-index-cli-0.4.3 llama-index-core-0.12.41 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.7.4 llama-index-llms-openai-0.4.4 llama-index-multi-modal-llms-openai-0.5.1 llama-index-program-openai-0.3.2 llama-index-question-gen-openai-0.3.1 llama-index-readers-file-0.4.9 llama-index-readers-llama-parse-0.4.0 llama-parse-0.6.30 marshmallow-3.26.1 mypy-extensions-1.1.0 pypdf-5.6.0 python-dotenv-1.1.0 striprtf-0.0.26 typing-inspect-0.9.0
# Requirement already satisfied: llama-index in /usr/local/lib/python3.11/dist-packages (0.12.41)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.9)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.41 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.12.41)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.7.4)
# Requirement already satisfied: llama-index-llms-openai<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.4)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.6,>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.2)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.9)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.84.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.1.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.41->llama-index) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (4.14.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.41->llama-index) (1.17.2)
# Requirement already satisfied: llama-cloud==0.1.23 in /usr/local/lib/python3.11/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.23)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from llama-cloud==0.1.23->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.4.26)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pandas<2.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<6,>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.6.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.30)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.41->llama-index) (1.20.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.41->llama-index) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.41->llama-index) (0.16.0)
# Requirement already satisfied: llama-cloud-services>=0.6.30 in /usr/local/lib/python3.11/dist-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.30)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.41->llama-index) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.41->llama-index) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.41->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.41->llama-index) (3.26.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-cloud-services>=0.6.30->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.41->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.41->llama-index) (3.0.2)
# Requirement already satisfied: llama-index-core in /usr/local/lib/python3.11/dist-packages (0.12.41)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (2.1.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (4.14.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.20.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core) (3.1.6)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core) (4.3.8)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core) (3.26.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core) (0.16.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->llama-index-core) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.0.0->llama-index-core) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.0.0->llama-index-core) (3.0.2)
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.5.4-py3-none-any.whl.metadata (458 bytes)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.32.4)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-huggingface) (0.12.41)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-huggingface) (4.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2.1.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2.11.5)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.17.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.52.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.15.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.20.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (3.1.6)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (4.3.8)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-huggingface) (3.2.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.20->autoawq) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->autoawq) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.20->autoawq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.20->autoawq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.20->autoawq) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.20->autoawq) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.20->autoawq) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 10.5 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.6 MB/s eta 0:00:00
# Building wheels for collected packages: autoawq
#   Building wheel for autoawq (setup.py) ... done
#   Created wheel for autoawq: filename=autoawq-0.2.9-py3-none-any.whl size=115106 sha256=d68e242646548ba56bf1103da9c72fe588c86ab93a222e1f57c7e6d18f7c6c58
#   Stored in directory: /root/.cache/pip/wheels/fa/31/e6/260073853a2419a05b7cd592d82db1e34abce58404854ef14d
# Successfully built autoawq
# Installing collected packages: fsspec, datasets, autoawq
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed autoawq-0.2.9 datasets-3.6.0 fsspec-2025.3.0
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pdf2image) (11.2.1)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.8 [186 kB]
# Fetched 186 kB in 0s (1,163 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.8_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.8) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.8) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-pxgf8ng9
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-pxgf8ng9
#   Resolved https://github.com/huggingface/transformers to commit 10627c1a0f6877ce6715b9537afe7fafb2a89edd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2025.4.26)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.53.0.dev0-py3-none-any.whl size=11411771 sha256=181419da7a24e25dec132c0d6372d22e898c706e09029e520f579d03aa58a0c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-13orpk7l/wheels/04/a3/f1/b88775f8e1665827525b19ac7590250f1038d947067beba9fb
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# Successfully installed transformers-4.53.0.dev0
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from decord) (2.0.2)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 90.2 MB/s eta 0:00:00
# Installing collected packages: decord
# Successfully installed decord-0.6.0
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.53.0.dev0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.schema import Document, QueryBundle
from llama_index.core.service_context import ServiceContext
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig, AutoModelForSequenceClassification
from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from llama_index.core import Settings
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import torch
import numpy as np
from huggingface_hub import HfFolder
from huggingface_hub import whoami
from llama_index.core.prompts import PromptTemplate
import textwrap
import os
from pathlib import Path
from google import genai
import PIL.Image
from pdf2image import convert_from_path
from llama_index.core import Document as LlamaIndexDocument, VectorStoreIndex
from langchain.schema import Document as LangChainDocument

# %%
from llama_index.core.schema import Document as LlamaDocument

# %%
def rerank_candidates_with_cross_encoder(query, candidates, model_name="hotchpotch/japanese-reranker-cross-encoder-xsmall-v1", device="cpu", threshold=0.7):
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  model = AutoModelForSequenceClassification.from_pretrained(model_name).to(device)

  pairs = [[query, candidate] for candidate in candidates]
  inputs = tokenizer(pairs, padding=True, truncation=True, return_tensors="pt").to(device)

  with torch.no_grad():
    outputs = model(**inputs)
    scores = torch.sigmoid(outputs.logits).squeeze(1).tolist()

  ranked_candidates = sorted(zip(candidates, scores), key=lambda x: x[1], reverse=True)
  ranked_candidates = [(candidate, score) for candidate, score in ranked_candidates if score >= threshold]
  return ranked_candidates

# %%
def query_engine(query, index, llm, top_k=5, threshold=0.7):
    import torch, textwrap
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    qe = index.as_query_engine(similarity_top_k=top_k)
    nodes = qe.query(QueryBundle(query_str=query)).source_nodes  # Node list

    candidates = [(n.text, n.metadata.get("page", "?")) for n in nodes]

    texts = [t for t, _ in candidates]
    ranked_scores = rerank_candidates_with_cross_encoder(query, texts,
                                                         device=device,
                                                         threshold=threshold)

    ranked_chunks = []
    for (txt, score) in ranked_scores:
        page = next(p for t, p in candidates if t == txt)
        ranked_chunks.append((txt, page, score))

    context = "\n\n".join([f"[p{pg}] {txt}" for txt, pg, _ in ranked_chunks])

    prompt = f"""
あなたは知識豊富な周南公立大学情報科学部情報科学科のアシスタントです。以下のルールに従って回答してください。

【思考手順】
- Let's think step by step.
- 最終回答は簡潔（100〜200字）でまとめる。
- 質問とコンテキストに矛盾がないか確認し、矛盾があればコンテキストを優先。

【出力ルール】
- 根拠ページを (pX) として文末に添える (例: …です。(p3))
- 無関係な情報は含めない。

【コンテキスト】
{context}

【質問】:{query}

【最終回答】:
"""

    return llm.generate([prompt])

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=False,
)

# %%
# !pip install huggingface_hub

from huggingface_hub import login
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

if HF_TOKEN:
    login(HF_TOKEN)
    print("Successfully logged in to Hugging Face!")
else:
    print("HF_TOKEN is not set. Please add it to the Colab secrets.")
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.4.26)
# Successfully logged in to Hugging Face!

# %%
model_id = "elyza/Llama-3-ELYZA-JP-8B-AWQ"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
        model_id,
        device_map="auto",
        torch_dtype=torch.bfloat16,
      )
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/900 [00:00<?, ?B/s]
# `torch.bfloat16` is not supported for AWQ CUDA kernels yet. Casting to `torch.float16`.
# model.safetensors.index.json:   0%|          | 0.00/63.5k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.05G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.68G [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/awq/__init__.py:21: DeprecationWarning:
# I have left this message as the final dev message to help you transition.
#
# Important Notice:
# - AutoAWQ is officially deprecated and will no longer be maintained.
# - The last tested configuration used Torch 2.6.0 and Transformers 4.51.3.
# - If future versions of Transformers break AutoAWQ compatibility, please report the issue to the Transformers project.
#
# Alternative:
# - AutoAWQ has been adopted by the vLLM Project: https://github.com/vllm-project/llm-compressor
#
# For further inquiries, feel free to reach out:
# - X: https://x.com/casper_hansen_
# - LinkedIn: https://www.linkedin.com/in/casper-hansen-804005170/
#
#   warnings.warn(_FINAL_DEV_MESSAGE, category=DeprecationWarning, stacklevel=1)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]

# %%
text_generation_pipeline = pipeline(
    "text-generation",
    model = model,
    tokenizer = tokenizer,
    max_new_tokens = 256,
    temperature = 0.8,
    do_sample=True,
)
# Out:
# Device set to use cuda:0

# %%
my_llm = HuggingFacePipeline(pipeline = text_generation_pipeline)
Settings.llm = my_llm
# Out:
# <ipython-input-11-887e6ed4a779>:1: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   my_llm = HuggingFacePipeline(pipeline = text_generation_pipeline)

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.53.0.dev0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: autoawq, llama-index-llms-huggingface, peft, sentence-transformers

# %%
embedding_model = HuggingFaceEmbedding(
    model_name="cl-nagoya/ruri-v3-310m",
    device="cuda",
    max_length = 2048,
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.78k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.83M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/6.72M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/968 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyCo82O3RxX88L2f3x-GTBu5FhxPQ97bCfg"

# %%
def extract_text(response):
    if response is None or not hasattr(response, 'candidates'):
        print("Error: Response is None or has no 'candidates' attribute")
        return ""
    extracted = ""
    for candidate in response.candidates:
        if not hasattr(candidate, 'content') or candidate.content is None:
            print("Error: Candidate has no 'content'")
            continue
        if not hasattr(candidate.content, 'parts') or candidate.content.parts is None:
            print("Error: Candidate content has no 'parts'")
            continue
        for part in candidate.content.parts:
            if hasattr(part, 'text'):
                extracted += part.text + "\n"
    return extracted.strip()

# %%
pdf_path = Path("/content/drive/MyDrive/experimental_file/experimental_file.pdf")

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

pages = convert_from_path(str(pdf_path), dpi=300)

pages = pages[:16]

CHUNKING_PROMPT = """\
OCR the following page into Markdown. Tables should be formatted as HTML.
Do not surround your output with triple backticks.
Chunk the document into sections of roughly 250 - 1000 words.
Surround each chunk with <chunk> and </chunk> tags.
Preserve as much content as possible, including headings, tables, etc.
Don't try to output any image.
"""

documents = []

for i, page in enumerate(pages):
    print(f"Processing Page {i+1}")
    try:
        response = client.models.generate_content(
            model="gemini-2.0-flash",
            contents=[CHUNKING_PROMPT, page]
        )
        print(f"API Response for Page {i+1}: {response}")
        ocr_text = extract_text(response)
        print(f"Raw OCR Text for Page {i+1}: '{ocr_text}'")
        document = Document(
            text=f"--- OCR Result for Page {i+1} ---\n{ocr_text}",
            metadata={"page": i+1}
        )
        documents.append(document)
        print(f"Document Text for Page {i+1}: '{document.text}'")
    except Exception as e:
        print(f"Error processing Page {i+1}: {e}")
        document = Document(
            text=f"--- OCR Result for Page {i+1} ---\n[Error: OCR Failed]",
            metadata={"page": i+1}
        )
        documents.append(document)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>卒業論文</td>
# <td>4通</td>
# <td></td>
# <td>◎</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <p>◎…卒業必修科目
# ○…選択科目</p>
# </chunk>'
# Document Text for Page 5: '--- OCR Result for Page 5 ---
# <chunk>
# 情報科学部情報科学科 授業科目表
# 2024年度入学 情報科学部情報科学科 授業科目表
# </chunk>
#
# <chunk>
# <table>
# <thead>
# <tr>
# <th>科目区分</th>
# <th>授業科目の名称</th>
# <th>配当年次</th>
# <th>単位数区分</th>
# <th>プログラム</th>
# <th>卒業要件</th>
# </tr>
# <tr>
# <th></th>
# <th></th>
# <th></th>
# <th>必修</th>
# <th>選択</th>
# <th>DS</th>
# <th>IE</th>
# <th>BA</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>総合科目</td>
# <td>人間形成と個性伸張のための科目群</td>
# <td>周南Well-being創生入門</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td>持続可能な社会とダイバーシティ</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>教養スポーツ実習Ⅰ</td>
# <td>1前</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>メンタルヘルス入門</td>
# <td>1前</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>教養スポーツ実習II</td>
# <td>1後</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>健康とスポーツ</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>人の健康生活</td>
# <td>1後</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>異文化コミュニケーション</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>周南Well-being創生論</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>健康と福祉</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>デザインシンキング</td>
# <td>1通</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>周南地域と産業</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>周南地域文化講座</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>自然災害と防災</td>
# <td>2前</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>アントレプレナーシップ入門</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ソーシャルアントレプレナーシップ</td>
# <td>2後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ワークショップデザインI</td>
# <td>2通</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ワークショップデザインⅡ</td>
# <td>3通</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ワークショップデザインⅢ</td>
# <td>4通</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>哲学</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>日本国憲法</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>社会学</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>生活と経済経営</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>ドイツ語Ⅰ</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>中国語I</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>韓国語Ⅰ</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>韓国語Ⅱ</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>中国語II</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# <tr><td></td>
# <td></td>
# <td>ドイツ語Ⅱ</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr><tr><td></td>
# <td></td>
# <td>教養ゼミ</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>留学英語</td>
# <td>1前</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td>リベラルアーツ科目群</td>
# <td>情報リテラシー</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>19単位
# (総合科目から必修を19単位修得)</td>
# </tr>
# </tbody>
# </table>
# </chunk>
#
# <chunk>
# <table>
# <thead>
# <tr>
# <th>科目区分</th>
# <th>授業科目の名称</th>
# <th>配当年次</th>
# <th>単位数区分</th>
# <th>プログラム</th>
# <th>卒業要件</th>
# </tr>
# <tr>
# <th></th>
# <th></th>
# <th></th>
# <th>必修</th>
# <th>選択</th>
# <th>DS</th>
# <th>IE</th>
# <th>BA</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>リテラシー科目群</td>
# <td>Python入門</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>コミュニケーション英語Ⅰ</td>
# <td>1前</td>
# <td></td>
# <td>1</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>キャリア形成活動I</td>
# <td>1通</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>アカデミックライティング</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>コミュニケーション英語Ⅱ</td>
# <td>|後</td>
# <td></td>
# <td>1</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>データサイエンス入門</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>情報倫理</td>
# <td>1後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ビジネス英会話</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>情報社会論</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>コミュニケーション英語ⅠⅡⅢ</td>
# <td>2前</td>
# <td></td>
# <td>1</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>キャリア形成活動Ⅱ</td>
# <td>2通</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>コミュニケーション英語IV</td>
# <td>2後</td>
# <td></td>
# <td>1</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ビジネス英作文</td>
# <td>2後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>総合英語中上級Ⅰ</td>
# <td>3前</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td>総合英語中上級Ⅱ</td>
# <td>3後</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>グローバル英語</td>
# <td>3後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td>学部基礎科目</td>
# <td></td>
# <td>情報科学概論</td>
# <td>1①</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>実社会とデータ分析</td>
# <td>1①</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>計算機概論</td>
# <td>1②</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>Python応用</td>
# <td>1②</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>データ分析基礎</td>
# <td>1②</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>線形代数基礎</td>
# <td>1③</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>VBAプログラミング</td>
# <td>1③</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>データの可視化</td>
# <td>1③</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>企業とデータ分析</td>
# <td>1③</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>微分積分基礎</td>
# <td>1④</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>地方創生とDX</td>
# <td>1③</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>確率統計基礎</td>
# <td>2①</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>AI・機械学習基礎</td>
# <td>2①</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>Javaプログラミング</td>
# <td>22</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>言語情報学</td>
# <td>22</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>Webアプリケーション開発</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>実践英語(AI)</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>実践英語(数学)</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>実践英語(情報)</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>社会調査法</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>情報行動心理学</td>
# <td>32</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td>コーパス言語学</td>
# <td>33</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>AI、コンピュータと人間</td>
# <td>34</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>データサイエンス概論</td>
# <td>1④</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>20単位
# (学部基礎科目から必修16単位、実践英
# 語から4単位修得)</td>
# </tr>
# </tbody>
# </table>
# </chunk>
#
# <chunk>
# <table>
# <thead>
# <tr>
# <th>科目区分</th>
# <th>授業科目の名称</th>
# <th>配当年次</th>
# <th>単位数区分</th>
# <th>プログラム</th>
# <th>卒業要件</th>
# </tr>
# <tr>
# <th></th>
# <th></th>
# <th></th>
# <th>必修</th>
# <th>選択</th>
# <th>DS</th>
# <th>IE</th>
# <th>BA</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>専門科目</td>
# <td>ニューラルネットワーク</td>
# <td>21</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>124単位
# (自由選択科目15
# 単位を含む)</td>
# </tr>
# <tr><td></td>
# <td>データサイエンスプログラム科目情報エンジニアリングプログラム科目ビジネスアナリティクスプログラム科目</td>
# <td>IoTとAI</td>
# <td>21</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>多変量解析</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>生体情報システム</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>モデリングの数理</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>数值解析</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>AI・自然言語処理</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>AI・推薦システム</td>
# <td>32</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>AI・画像情報処理</td>
# <td>33</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>質的データ分析</td>
# <td>34</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>情報エンジニアリング概論</td>
# <td>1④</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>データベース</td>
# <td>21</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>90単位
# (選択科目36単位
# を含む)</td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>アルゴリズムとデータ構造</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>プログラミング</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>情報ネットワークとセキュリティ</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ソフトウェア工学</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>コンピュータグラフィックス</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>組み込みシステム</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ヒューマンコンピュータインタラクション</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>医療情報システム</td>
# <td>32</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>モバイルコンピューティング</td>
# <td>33</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>ビジネスアナリティクス概論</td>
# <td>1④</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>感性情報処理</td>
# <td>21</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>22単位
# (主とするプログラムから必修を8単
# 位、選択を14単位修得)</td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>最適化モデリング</td>
# <td>22</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>会計情報と経営</td>
# <td>22</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>経営と数理モデル</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>インターネットマーケティング</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>シミュレーション</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>品質管理とデータ分析</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>マーケティング・リサーチ</td>
# <td>32</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr><tr><td></td>
# <td></td>
# <td>フィンテック・ブロックチェーン</td>
# <td>33</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>金融データ解析</td>
# <td>34</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>認知・感性とデータ分析</td>
# <td>23</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>大規模・オープンデータ分析</td>
# <td>24</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>生体情報分析</td>
# <td>31</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td>演習科目</td>
# <td>専門ゼミ1</td>
# <td>3前</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td>8単位
# (演習科目から必修を8単位修得)</td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>専門ゼミ2</td>
# <td>3後</td>
# <td></td>
# <td>2</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>卒業研究</td>
# <td>4通</td>
# <td></td>
# <td>4</td>
# <td>◎</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td>他学科専門科目</td>
# <td>地域観光まちづくり論</td>
# <td>1前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td>4単位
# (他学科専門科目から
# 選択を4単位修得)</td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>マーケティング論Ⅰ</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>地域マネジメント論</td>
# <td>2前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>スポーツ産業学</td>
# <td>3前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>スポーツマネジメント</td>
# <td>3後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>スポーツツーリズム論</td>
# <td>3後</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>保健医療と福祉</td>
# <td>4前</td>
# <td></td>
# <td>2</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>医療経済学</td>
# <td>4後</td>
# <td></td>
# <td>1</td>
# <td>○</td>
# <td></td>
# <td></td>
# </tr>
# <tr><td></td>
# <td></td>
# <td>卒業論文</td>
# <td>4通</td>
# <td></td>
# <td>◎</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <p>◎…卒業必修科目
# ○…選択科目</p>
# </chunk>'
# Processing Page 6
# API Response for Page 6: candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='<chunk>\n情報科学部情報科学科\n専門ゼミ1,専門ゼミ2, 卒業研究,卒業論文について\n情報科学部では高度の学術を学修するため、3年次前期に専門ゼミ1、3年次後期に専門ゼミ2、4年次に卒業研究をそれぞれ履修し、4年次末に卒業論文\nを提出し、審査に合格することを義務付けています。ここでは、その流れについて説明します。\nスケジュールの概要\n情報科学部のカリキュラムの実施に際し、以下のアドミッション・ポリシーを満たす学生を広く募集し、受け入れます。\n\n</chunk>\n\n<chunk>\n<table>\n<thead>\n<tr>\n<th></th><th></th><th></th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>2年次</td><td>7月</td><td>ゼミ配属希望アンケート (9月に結果公表)</td>\n</tr>\n<tr>\n<td></td><td></td><td>第3・4クオータブレイク ゼミ説明会</td>\n</tr>\n<tr>\n<td></td><td>12月~1月</td><td>専門ゼミ1担当者訪問(事前予約すること)</td>\n</tr>\n<tr>\n<td></td><td>2月(定期試験最終日)</td><td>専門ゼミ1配属希望届締め切り</td>\n</tr>\n<tr>\n<td></td><td>3月中旬</td><td>専門ゼミ1配属発表</td>\n</tr>\n<tr>\n<td>3年次</td><td></td><td>3年前期 専門ゼミ1の履修</td>\n</tr>\n<tr>\n<td></td><td>7月</td><td>専門ゼミ2配属希望届締め切り (希望者のみ)</td>\n</tr>\n<tr>\n<td></td><td>3年後期</td><td>専門ゼミ2の履修</td>\n</tr>\n<tr>\n<td></td><td>1月</td><td>卒業研究配属希望締め切り (希望者のみ)</td>\n</tr>\n<tr>\n<td>4年次</td><td></td><td>4年(通年) 卒業研究</td>\n</tr>\n<tr>\n<td></td><td></td><td>第1・2クオーターブレイク 卒業研究テーマ1分発表会</td>\n<tr>\n<td></td><td></td><td>卒業論文主査・副查決定</td>\n</tr>\n<tr>\n<td></td><td></td><td>第3・4クオーターブレイク 卒業研究進捗3分発表会</td>\n</tr>\n<tr>\n<td></td><td>1月末</td><td>卒業論文提出締め切り</td>\n</tr>\n<tr>\n<td></td><td>2月前半</td><td>卒業論文5分発表会</td>\n</tr>\n<tr>\n<td></td><td>2月後半</td><td>卒業論文審査</td>\n</tr>\n<tr>\n<td></td><td>3月1日</td><td>卒業論文最終版提出締め切り</td>\n</tr>\n</tbody>\n</table>\n\n</chunk>\n\n<chunk>\n注意点\n1 上記スケジュールの正確な日程については年度ごとに発表します。また、専門ゼミ1、専門ゼミ2、卒業研究については学期当初に担当教員と配属\n学生との相談により、その実施時間割等を決めることとするため、時間割上は集中講義扱いになっています。\n2 専門ゼミ1、専門ゼミ2、卒業研究は2年間を通じて一つの専門分野・領域の学修を深め、その成果を卒業論文にまとめることで高度の学術を修得す\nるためにあります。必要に応じた配属変更は以下の7、8のように可能ですが、専門ゼミ1の希望届は十分慎重に考えた上で提出してください。\n3 専門ゼミ1、専門ゼミ2、卒業研究は通常の授業科目と異なり、その高度の学術学修のため、各配属学生全体及び各配属学生ごとにゼミナール形式の\n他、個別指導、勉強会、読書会など多様な形態の学習を組み合わせるため、2年次に行われるゼミ説明会の説明等をよく確認してください。\n4 専門ゼミ1については各教員ごとに受入可能人数 (その合計は専門ゼミ1履修予定者数の1.2倍程度)がゼミ説明会時に示されます。\n5 専門ゼミ1の後半 (第2クオーターに当たる時期)についてはインターンシップ等を奨励するため、必要に応じてオンライン等の指導を併用します。\n6 専門ゼミ1の配属については希望届 (第10希望まで記す予定)をもとに1・2年次のGPA を参考にして決定されます。\n7 専門ゼミ2について変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次前期までのGPAを参考にして決定されます。\n8 卒業研究の配属は原則として専門ゼミ2と同じですが、変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次までの\nGPA を参考にして決定されます。\n\n</chunk>\n\n<chunk>\n9 卒業論文は1月末に定められた形式で完成稿を提出しなければなりません。ただし、その後の審査を経て合格したものについて、必要な修正等を加\nえた上で、審査合格者全員が3月1日までに最終版を改めて提出することとします。卒業論文最終版は学部で保管し、のちの学生らも閲覧しますの\nで、十分な校正等をしたものを提出しなければなりません。\n10 専門ゼミ1、専門ゼミ2、卒業研究の担当教員は各期のチューターとして、安全かつ健全な学修・生活等についても助言・指導します。\n11 早期卒業、協定校留学、休学などの理由で教育上有益とみなす場合は、専門ゼミ1、専門ゼミ2、卒業研究の履修時期及び履修期間、卒業論文の提出\n時期について変更されることがあります。この詳細については2年次に行われるゼミ説明会で説明するとともに、その詳細は文書で公表されます。\n12 その他、特別に配慮すべき場合に、配属の変更等を行なう場合があります。\n13 この説明は2024年度入学生に適用されますが、学生の不利益にならない改訂を施すことがあります。その際は十分な猶予期間をもって公表します。\n</chunk>')], role='model'), citation_metadata=None, finish_message=None, token_count=None, finish_reason=<FinishReason.STOP: 'STOP'>, url_context_metadata=None, avg_logprobs=-0.005198379691320521, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=None)] create_time=None response_id=None model_version='gemini-2.0-flash' prompt_feedback=None usage_metadata=GenerateContentResponseUsageMetadata(cache_tokens_details=None, cached_content_token_count=None, candidates_token_count=1310, candidates_tokens_details=[ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=1310)], prompt_token_count=3440, prompt_tokens_details=[ModalityTokenCount(modality=<MediaModality.IMAGE: 'IMAGE'>, token_count=3354), ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=86)], thoughts_token_count=None, tool_use_prompt_token_count=None, tool_use_prompt_tokens_details=None, total_token_count=4750, traffic_type=None) automatic_function_calling_history=[] parsed=None
# Raw OCR Text for Page 6: '<chunk>
# 情報科学部情報科学科
# 専門ゼミ1,専門ゼミ2, 卒業研究,卒業論文について
# 情報科学部では高度の学術を学修するため、3年次前期に専門ゼミ1、3年次後期に専門ゼミ2、4年次に卒業研究をそれぞれ履修し、4年次末に卒業論文
# を提出し、審査に合格することを義務付けています。ここでは、その流れについて説明します。
# スケジュールの概要
# 情報科学部のカリキュラムの実施に際し、以下のアドミッション・ポリシーを満たす学生を広く募集し、受け入れます。
#
# </chunk>
#
# <chunk>
# <table>
# <thead>
# <tr>
# <th></th><th></th><th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2年次</td><td>7月</td><td>ゼミ配属希望アンケート (9月に結果公表)</td>
# </tr>
# <tr>
# <td></td><td></td><td>第3・4クオータブレイク ゼミ説明会</td>
# </tr>
# <tr>
# <td></td><td>12月~1月</td><td>専門ゼミ1担当者訪問(事前予約すること)</td>
# </tr>
# <tr>
# <td></td><td>2月(定期試験最終日)</td><td>専門ゼミ1配属希望届締め切り</td>
# </tr>
# <tr>
# <td></td><td>3月中旬</td><td>専門ゼミ1配属発表</td>
# </tr>
# <tr>
# <td>3年次</td><td></td><td>3年前期 専門ゼミ1の履修</td>
# </tr>
# <tr>
# <td></td><td>7月</td><td>専門ゼミ2配属希望届締め切り (希望者のみ)</td>
# </tr>
# <tr>
# <td></td><td>3年後期</td><td>専門ゼミ2の履修</td>
# </tr>
# <tr>
# <td></td><td>1月</td><td>卒業研究配属希望締め切り (希望者のみ)</td>
# </tr>
# <tr>
# <td>4年次</td><td></td><td>4年(通年) 卒業研究</td>
# </tr>
# <tr>
# <td></td><td></td><td>第1・2クオーターブレイク 卒業研究テーマ1分発表会</td>
# <tr>
# <td></td><td></td><td>卒業論文主査・副查決定</td>
# </tr>
# <tr>
# <td></td><td></td><td>第3・4クオーターブレイク 卒業研究進捗3分発表会</td>
# </tr>
# <tr>
# <td></td><td>1月末</td><td>卒業論文提出締め切り</td>
# </tr>
# <tr>
# <td></td><td>2月前半</td><td>卒業論文5分発表会</td>
# </tr>
# <tr>
# <td></td><td>2月後半</td><td>卒業論文審査</td>
# </tr>
# <tr>
# <td></td><td>3月1日</td><td>卒業論文最終版提出締め切り</td>
# </tr>
# </tbody>
# </table>
#
# </chunk>
#
# <chunk>
# 注意点
# 1 上記スケジュールの正確な日程については年度ごとに発表します。また、専門ゼミ1、専門ゼミ2、卒業研究については学期当初に担当教員と配属
# 学生との相談により、その実施時間割等を決めることとするため、時間割上は集中講義扱いになっています。
# 2 専門ゼミ1、専門ゼミ2、卒業研究は2年間を通じて一つの専門分野・領域の学修を深め、その成果を卒業論文にまとめることで高度の学術を修得す
# るためにあります。必要に応じた配属変更は以下の7、8のように可能ですが、専門ゼミ1の希望届は十分慎重に考えた上で提出してください。
# 3 専門ゼミ1、専門ゼミ2、卒業研究は通常の授業科目と異なり、その高度の学術学修のため、各配属学生全体及び各配属学生ごとにゼミナール形式の
# 他、個別指導、勉強会、読書会など多様な形態の学習を組み合わせるため、2年次に行われるゼミ説明会の説明等をよく確認してください。
# 4 専門ゼミ1については各教員ごとに受入可能人数 (その合計は専門ゼミ1履修予定者数の1.2倍程度)がゼミ説明会時に示されます。
# 5 専門ゼミ1の後半 (第2クオーターに当たる時期)についてはインターンシップ等を奨励するため、必要に応じてオンライン等の指導を併用します。
# 6 専門ゼミ1の配属については希望届 (第10希望まで記す予定)をもとに1・2年次のGPA を参考にして決定されます。
# 7 専門ゼミ2について変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次前期までのGPAを参考にして決定されます。
# 8 卒業研究の配属は原則として専門ゼミ2と同じですが、変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次までの
# GPA を参考にして決定されます。
#
# </chunk>
#
# <chunk>
# 9 卒業論文は1月末に定められた形式で完成稿を提出しなければなりません。ただし、その後の審査を経て合格したものについて、必要な修正等を加
# えた上で、審査合格者全員が3月1日までに最終版を改めて提出することとします。卒業論文最終版は学部で保管し、のちの学生らも閲覧しますの
# で、十分な校正等をしたものを提出しなければなりません。
# 10 専門ゼミ1、専門ゼミ2、卒業研究の担当教員は各期のチューターとして、安全かつ健全な学修・生活等についても助言・指導します。
# 11 早期卒業、協定校留学、休学などの理由で教育上有益とみなす場合は、専門ゼミ1、専門ゼミ2、卒業研究の履修時期及び履修期間、卒業論文の提出
# 時期について変更されることがあります。この詳細については2年次に行われるゼミ説明会で説明するとともに、その詳細は文書で公表されます。
# 12 その他、特別に配慮すべき場合に、配属の変更等を行なう場合があります。
# 13 この説明は2024年度入学生に適用されますが、学生の不利益にならない改訂を施すことがあります。その際は十分な猶予期間をもって公表します。
# </chunk>'
# Document Text for Page 6: '--- OCR Result for Page 6 ---
# <chunk>
# 情報科学部情報科学科
# 専門ゼミ1,専門ゼミ2, 卒業研究,卒業論文について
# 情報科学部では高度の学術を学修するため、3年次前期に専門ゼミ1、3年次後期に専門ゼミ2、4年次に卒業研究をそれぞれ履修し、4年次末に卒業論文
# を提出し、審査に合格することを義務付けています。ここでは、その流れについて説明します。
# スケジュールの概要
# 情報科学部のカリキュラムの実施に際し、以下のアドミッション・ポリシーを満たす学生を広く募集し、受け入れます。
#
# </chunk>
#
# <chunk>
# <table>
# <thead>
# <tr>
# <th></th><th></th><th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2年次</td><td>7月</td><td>ゼミ配属希望アンケート (9月に結果公表)</td>
# </tr>
# <tr>
# <td></td><td></td><td>第3・4クオータブレイク ゼミ説明会</td>
# </tr>
# <tr>
# <td></td><td>12月~1月</td><td>専門ゼミ1担当者訪問(事前予約すること)</td>
# </tr>
# <tr>
# <td></td><td>2月(定期試験最終日)</td><td>専門ゼミ1配属希望届締め切り</td>
# </tr>
# <tr>
# <td></td><td>3月中旬</td><td>専門ゼミ1配属発表</td>
# </tr>
# <tr>
# <td>3年次</td><td></td><td>3年前期 専門ゼミ1の履修</td>
# </tr>
# <tr>
# <td></td><td>7月</td><td>専門ゼミ2配属希望届締め切り (希望者のみ)</td>
# </tr>
# <tr>
# <td></td><td>3年後期</td><td>専門ゼミ2の履修</td>
# </tr>
# <tr>
# <td></td><td>1月</td><td>卒業研究配属希望締め切り (希望者のみ)</td>
# </tr>
# <tr>
# <td>4年次</td><td></td><td>4年(通年) 卒業研究</td>
# </tr>
# <tr>
# <td></td><td></td><td>第1・2クオーターブレイク 卒業研究テーマ1分発表会</td>
# <tr>
# <td></td><td></td><td>卒業論文主査・副查決定</td>
# </tr>
# <tr>
# <td></td><td></td><td>第3・4クオーターブレイク 卒業研究進捗3分発表会</td>
# </tr>
# <tr>
# <td></td><td>1月末</td><td>卒業論文提出締め切り</td>
# </tr>
# <tr>
# <td></td><td>2月前半</td><td>卒業論文5分発表会</td>
# </tr>
# <tr>
# <td></td><td>2月後半</td><td>卒業論文審査</td>
# </tr>
# <tr>
# <td></td><td>3月1日</td><td>卒業論文最終版提出締め切り</td>
# </tr>
# </tbody>
# </table>
#
# </chunk>
#
# <chunk>
# 注意点
# 1 上記スケジュールの正確な日程については年度ごとに発表します。また、専門ゼミ1、専門ゼミ2、卒業研究については学期当初に担当教員と配属
# 学生との相談により、その実施時間割等を決めることとするため、時間割上は集中講義扱いになっています。
# 2 専門ゼミ1、専門ゼミ2、卒業研究は2年間を通じて一つの専門分野・領域の学修を深め、その成果を卒業論文にまとめることで高度の学術を修得す
# るためにあります。必要に応じた配属変更は以下の7、8のように可能ですが、専門ゼミ1の希望届は十分慎重に考えた上で提出してください。
# 3 専門ゼミ1、専門ゼミ2、卒業研究は通常の授業科目と異なり、その高度の学術学修のため、各配属学生全体及び各配属学生ごとにゼミナール形式の
# 他、個別指導、勉強会、読書会など多様な形態の学習を組み合わせるため、2年次に行われるゼミ説明会の説明等をよく確認してください。
# 4 専門ゼミ1については各教員ごとに受入可能人数 (その合計は専門ゼミ1履修予定者数の1.2倍程度)がゼミ説明会時に示されます。
# 5 専門ゼミ1の後半 (第2クオーターに当たる時期)についてはインターンシップ等を奨励するため、必要に応じてオンライン等の指導を併用します。
# 6 専門ゼミ1の配属については希望届 (第10希望まで記す予定)をもとに1・2年次のGPA を参考にして決定されます。
# 7 専門ゼミ2について変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次前期までのGPAを参考にして決定されます。
# 8 卒業研究の配属は原則として専門ゼミ2と同じですが、変更希望届を出した場合、各教員ごとの受入可能人数の範囲内で、1年次から3年次までの
# GPA を参考にして決定されます。
#
# </chunk>
#
# <chunk>
# 9 卒業論文は1月末に定められた形式で完成稿を提出しなければなりません。ただし、その後の審査を経て合格したものについて、必要な修正等を加
# えた上で、審査合格者全員が3月1日までに最終版を改めて提出することとします。卒業論文最終版は学部で保管し、のちの学生らも閲覧しますの
# で、十分な校正等をしたものを提出しなければなりません。
# 10 専門ゼミ1、専門ゼミ2、卒業研究の担当教員は各期のチューターとして、安全かつ健全な学修・生活等についても助言・指導します。
# 11 早期卒業、協定校留学、休学などの理由で教育上有益とみなす場合は、専門ゼミ1、専門ゼミ2、卒業研究の履修時期及び履修期間、卒業論文の提出
# 時期について変更されることがあります。この詳細については2年次に行われるゼミ説明会で説明するとともに、その詳細は文書で公表されます。
# 12 その他、特別に配慮すべき場合に、配属の変更等を行なう場合があります。
# 13 この説明は2024年度入学生に適用されますが、学生の不利益にならない改訂を施すことがあります。その際は十分な猶予期間をもって公表します。
# </chunk>'
# Processing Page 7
# API Response for Page 7: candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='<chunk>\n履修モデルについて\n\n3つのプログラム\n\n情報科学は、生活のあらゆるところに関係しており、多くの分野が相\n互に関連し合って成り立っています。情報科学部では広く学んでいただ\nくとともに、関心のある分野を深く体系的に学んでいただくため、プロ\nグラム制を採用しています。\n\nプログラム制とは\n入学前または入学後に学科や専攻を一つ選ぶのではなく、広く情報科\n学の諸分野を学びつつ、卒業時にはどれか一つ以上のプログラムでまと\nまった学修を行ないます。関心が変わった等で、途中でプログラムを変\n更するのも自由にできますし、2つのプログラムを併修することもでき\nます。情報科学部には、ビジネスアナリティクス、データサイエンス、\n情報エンジニアリングの3つのプログラムがあります。\n</chunk>\n\n<chunk>\n<table>\n  <tr>\n    <td>\n      <b>基礎を固める</b>\n      <br>\n      総合科目・学部共通科目など\n    </td>\n    <td>\n      <b>専門を鍛える</b>\n      <br>\n      3つのプログラムから選択して習得\n      <br>\n      選択したプログラムの能力を集中して高める\n      <br>\n      2つ以上のプログラムへの挑戦も可能\n      <br>\n      <br>\n      ビジネスアナリティクスプログラム\n      <br>\n      <br>\n      データサイエンスプログラム\n      <br>\n      <br>\n      情報エンジニアリングプログラム\n    </td>\n    <td>\n      <b>実践力を高める</b>\n      <br>\n      専門ゼミ・卒業研究\n    </td>\n  </tr>\n</table>\n</chunk>\n\n<chunk>\nビジネスアナリティクス・プログラム\n現代ビジネスのキーの一つは、データを使った経営情報分析です。また、情報科学技術を活用した金融取引や金融分析はフィンテックとも言われ、\n注目を集めています。ビジネスアナリティクス・プログラムでは、こうしたビジネス関連の情報科学技術を学びます。\n\n[科目例] フィンテック・ブロックチェーン\nブロックチェーンとは, Bitcoin などに代表される仮想通貨の基盤であり、暗号技術によって取引履歴をセキュアかつ分散的に記録・管理する技\n術です。ブロックチェーン実装のために必要となる要素技術だけではなく、金融業における活用についても概観し、基礎から応用まで幅広く学\nびます。\n</chunk>\n\n<chunk>\nデータサイエンス・プログラム\nインターネットの普及等により、私たちの暮らしのあらゆる面で大量のデータが集まるようになり、機械学習等を使った高度な分析とその活用が求められ\nるようになりました。データサイエンス・プログラムでは、こうした大規模なデータをどのように分析・活用するかを学びます。\n\n[科目例] IoT と AI\n人工知能(Artificial Intelligence) とモノのインターネット (IoT) を統合した概念である Artifical Intelligence of Things (AloT) も誕生して\nおり、今後、社会のスマート化を目指していく上でAIとIoTの協調が重要視されています。この科目では、IoT および AI の基礎, IoTとAIの協調に\nついて体系的に学びます。\n</chunk>\n\n<chunk>\n情報エンジニアリング・プログラム\n情報科学は現代社会のインフラストラクチャーを支えるものであり、さまざまなシステムやネットワークを構築する人材は今後ますます必要とされてい\nます。情報エンジニアリング・プログラムでは、そうした構築の基礎となるプログラミングと関連知識を学びます。\n\n[科目例] 情報ネットワークとセキュリティ\n現在ではインターネットを中心とした情報ネットワークが生活の基盤となり、コンピュータやモバイル端末だけではなく、家電などもネットワークに\n接続されるようになりました。本科目では、情報ネットワークの基本的な知識・技術だけに留まらず、情報システムやネットワークを通じて提供され\nるサービスに存在する脆弱性やリスクに対応するためのセキュリティについて学びます。\n</chunk>\n')], role='model'), citation_metadata=None, finish_message=None, token_count=None, finish_reason=<FinishReason.STOP: 'STOP'>, url_context_metadata=None, avg_logprobs=-0.013724130207143706, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=None)] create_time=None response_id=None model_version='gemini-2.0-flash' prompt_feedback=None usage_metadata=GenerateContentResponseUsageMetadata(cache_tokens_details=None, cached_content_token_count=None, candidates_token_count=838, candidates_tokens_details=[ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=838)], prompt_token_count=3440, prompt_tokens_details=[ModalityTokenCount(modality=<MediaModality.IMAGE: 'IMAGE'>, token_count=3354), ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=86)], thoughts_token_count=None, tool_use_prompt_token_count=None, tool_use_prompt_tokens_details=None, total_token_count=4278, traffic_type=None) automatic_function_calling_history=[] parsed=None
# Raw OCR Text for Page 7: '<chunk>
# 履修モデルについて
#
# 3つのプログラム
#
# 情報科学は、生活のあらゆるところに関係しており、多くの分野が相
# 互に関連し合って成り立っています。情報科学部では広く学んでいただ
# くとともに、関心のある分野を深く体系的に学んでいただくため、プロ
# グラム制を採用しています。
#
# プログラム制とは
# 入学前または入学後に学科や専攻を一つ選ぶのではなく、広く情報科
# 学の諸分野を学びつつ、卒業時にはどれか一つ以上のプログラムでまと
# まった学修を行ないます。関心が変わった等で、途中でプログラムを変
# 更するのも自由にできますし、2つのプログラムを併修することもでき
# ます。情報科学部には、ビジネスアナリティクス、データサイエンス、
# 情報エンジニアリングの3つのプログラムがあります。
# </chunk>
#
# <chunk>
# <table>
#   <tr>
#     <td>
#       <b>基礎を固める</b>
#       <br>
#       総合科目・学部共通科目など
#     </td>
#     <td>
#       <b>専門を鍛える</b>
#       <br>
#       3つのプログラムから選択して習得
#       <br>
#       選択したプログラムの能力を集中して高める
#       <br>
#       2つ以上のプログラムへの挑戦も可能
#       <br>
#       <br>
#       ビジネスアナリティクスプログラム
#       <br>
#       <br>
#       データサイエンスプログラム
#       <br>
#       <br>
#       情報エンジニアリングプログラム
#     </td>
#     <td>
#       <b>実践力を高める</b>
#       <br>
#       専門ゼミ・卒業研究
#     </td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# ビジネスアナリティクス・プログラム
# 現代ビジネスのキーの一つは、データを使った経営情報分析です。また、情報科学技術を活用した金融取引や金融分析はフィンテックとも言われ、
# 注目を集めています。ビジネスアナリティクス・プログラムでは、こうしたビジネス関連の情報科学技術を学びます。
#
# [科目例] フィンテック・ブロックチェーン
# ブロックチェーンとは, Bitcoin などに代表される仮想通貨の基盤であり、暗号技術によって取引履歴をセキュアかつ分散的に記録・管理する技
# 術です。ブロックチェーン実装のために必要となる要素技術だけではなく、金融業における活用についても概観し、基礎から応用まで幅広く学
# びます。
# </chunk>
#
# <chunk>
# データサイエンス・プログラム
# インターネットの普及等により、私たちの暮らしのあらゆる面で大量のデータが集まるようになり、機械学習等を使った高度な分析とその活用が求められ
# るようになりました。データサイエンス・プログラムでは、こうした大規模なデータをどのように分析・活用するかを学びます。
#
# [科目例] IoT と AI
# 人工知能(Artificial Intelligence) とモノのインターネット (IoT) を統合した概念である Artifical Intelligence of Things (AloT) も誕生して
# おり、今後、社会のスマート化を目指していく上でAIとIoTの協調が重要視されています。この科目では、IoT および AI の基礎, IoTとAIの協調に
# ついて体系的に学びます。
# </chunk>
#
# <chunk>
# 情報エンジニアリング・プログラム
# 情報科学は現代社会のインフラストラクチャーを支えるものであり、さまざまなシステムやネットワークを構築する人材は今後ますます必要とされてい
# ます。情報エンジニアリング・プログラムでは、そうした構築の基礎となるプログラミングと関連知識を学びます。
#
# [科目例] 情報ネットワークとセキュリティ
# 現在ではインターネットを中心とした情報ネットワークが生活の基盤となり、コンピュータやモバイル端末だけではなく、家電などもネットワークに
# 接続されるようになりました。本科目では、情報ネットワークの基本的な知識・技術だけに留まらず、情報システムやネットワークを通じて提供され
# るサービスに存在する脆弱性やリスクに対応するためのセキュリティについて学びます。
# </chunk>'
# Document Text for Page 7: '--- OCR Result for Page 7 ---
# <chunk>
# 履修モデルについて
#
# 3つのプログラム
#
# 情報科学は、生活のあらゆるところに関係しており、多くの分野が相
# 互に関連し合って成り立っています。情報科学部では広く学んでいただ
# くとともに、関心のある分野を深く体系的に学んでいただくため、プロ
# グラム制を採用しています。
#
# プログラム制とは
# 入学前または入学後に学科や専攻を一つ選ぶのではなく、広く情報科
# 学の諸分野を学びつつ、卒業時にはどれか一つ以上のプログラムでまと
# まった学修を行ないます。関心が変わった等で、途中でプログラムを変
# 更するのも自由にできますし、2つのプログラムを併修することもでき
# ます。情報科学部には、ビジネスアナリティクス、データサイエンス、
# 情報エンジニアリングの3つのプログラムがあります。
# </chunk>
#
# <chunk>
# <table>
#   <tr>
#     <td>
#       <b>基礎を固める</b>
#       <br>
#       総合科目・学部共通科目など
#     </td>
#     <td>
#       <b>専門を鍛える</b>
#       <br>
#       3つのプログラムから選択して習得
#       <br>
#       選択したプログラムの能力を集中して高める
#       <br>
#       2つ以上のプログラムへの挑戦も可能
#       <br>
#       <br>
#       ビジネスアナリティクスプログラム
#       <br>
#       <br>
#       データサイエンスプログラム
#       <br>
#       <br>
#       情報エンジニアリングプログラム
#     </td>
#     <td>
#       <b>実践力を高める</b>
#       <br>
#       専門ゼミ・卒業研究
#     </td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# ビジネスアナリティクス・プログラム
# 現代ビジネスのキーの一つは、データを使った経営情報分析です。また、情報科学技術を活用した金融取引や金融分析はフィンテックとも言われ、
# 注目を集めています。ビジネスアナリティクス・プログラムでは、こうしたビジネス関連の情報科学技術を学びます。
#
# [科目例] フィンテック・ブロックチェーン
# ブロックチェーンとは, Bitcoin などに代表される仮想通貨の基盤であり、暗号技術によって取引履歴をセキュアかつ分散的に記録・管理する技
# 術です。ブロックチェーン実装のために必要となる要素技術だけではなく、金融業における活用についても概観し、基礎から応用まで幅広く学
# びます。
# </chunk>
#
# <chunk>
# データサイエンス・プログラム
# インターネットの普及等により、私たちの暮らしのあらゆる面で大量のデータが集まるようになり、機械学習等を使った高度な分析とその活用が求められ
# るようになりました。データサイエンス・プログラムでは、こうした大規模なデータをどのように分析・活用するかを学びます。
#
# [科目例] IoT と AI
# 人工知能(Artificial Intelligence) とモノのインターネット (IoT) を統合した概念である Artifical Intelligence of Things (AloT) も誕生して
# おり、今後、社会のスマート化を目指していく上でAIとIoTの協調が重要視されています。この科目では、IoT および AI の基礎, IoTとAIの協調に
# ついて体系的に学びます。
# </chunk>
#
# <chunk>
# 情報エンジニアリング・プログラム
# 情報科学は現代社会のインフラストラクチャーを支えるものであり、さまざまなシステムやネットワークを構築する人材は今後ますます必要とされてい
# ます。情報エンジニアリング・プログラムでは、そうした構築の基礎となるプログラミングと関連知識を学びます。
#
# [科目例] 情報ネットワークとセキュリティ
# 現在ではインターネットを中心とした情報ネットワークが生活の基盤となり、コンピュータやモバイル端末だけではなく、家電などもネットワークに
# 接続されるようになりました。本科目では、情報ネットワークの基本的な知識・技術だけに留まらず、情報システムやネットワークを通じて提供され
# るサービスに存在する脆弱性やリスクに対応するためのセキュリティについて学びます。
# </chunk>'
# Processing Page 8
# API Response for Page 8: candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='<chunk>\n情報科学部情報科学科 履修モデル\n履修モデル データサイエンスプログラム\n\n<table border="1">\n<tr>\n<th colspan="2">1年次(40単位)</th>\n<th colspan="2">2年次(42単位)</th>\n<th colspan="2">3年次(38単位)</th>\n<th>4年次(6単位)</th>\n</tr>\n<tr>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th></th>\n</tr>\n<tr>\n<td>\n総合科目\n<ul>\n<li>教養ゼミ (2)</li>\n<li>Python入門(2)</li>\n<li>教養スポーツ実習Ⅰ (1)</li>\n<li>コミュニケーション英語Ⅰ (1)</li>\n<li>キャリア形成活動Ⅰ (2) ※通年</li>\n<li>周南Well-being創生入門(2)</li>\n</ul>\n</td>\n<td>\n総合科目\n<ul>\n<li>情報倫理(2)</li>\n<li>コミュニケーション英語ⅠⅡ (1)</li>\n<li>健康とスポーツ (2)</li>\n<li>人の健康生活 (1)</li>\n</ul>\n</td>\n<td>\n総合科目\n<ul>\n<li>周南Well-being創生論(2)</li>\n<li>情報社会論(2)</li>\n<li>コミュニケーション英語Ⅲ (1)</li>\n</ul>\n</td>\n<td>\n総合科目\n<ul>\n<li>コミュニケーション英語IV (1)</li>\n</ul>\n</td>\n<td>\n</td>\n<td>\n</td>\n<td rowspan="6" align="center">卒業研究(4)</td>\n</tr>\n<tr>\n<td>\n学部基礎領域科目\n<ul>\n<li>情報科学概論(2)</li>\n<li>計算機概論(2)</li>\n<li>実社会とデータ分析(2)</li>\n<li>Python応用(2)</li>\n<li>データ分析基礎(2)</li>\n</ul>\n</td>\n<td>\n学部基礎領域科目\n<ul>\n<li>地方創生とDX (2)</li>\n<li>VBAプログラミング (2)</li>\n<li>線形代数基礎(2)</li>\n<li>微分積分基礎(2)</li>\n<li>データの可視化(2)</li>\n</ul>\n</td>\n<td>\n学部基礎領域科目\n<ul>\n<li>AI・機械学習基礎(2)</li>\n<li>確率統計基礎(2)</li>\n<li>Javaプログラミング (2)</li>\n<li>言語情報学(2)</li>\n</ul>\n</td>\n<td>\n学部基礎領域科目\n<ul>\n<li>実践英語(AI) (2) ※2</li>\n<li>実践英語(数学) (2) ※2</li>\n</ul>\n</td>\n<td>\n学部基礎領域科目\n<ul>\n<li>実践英語(情報) (2) ※2</li>\n<li>社会調査法(2)</li>\n<li>情報行動心理学(2)</li>\n</ul>\n</td>\n<td>\n学部基礎領域科目\n<ul>\n<li>コーパス言語学(2)</li>\n<li>AI、コンピュータと人間 (2)</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td>\nデータサイエンス\nプログラム科目\n<ul>\n<li>データサイエンス概論 (2) ※1</li>\n</ul>\n</td>\n<td>\nデータサイエンス\nプログラム科目\n<ul>\n<li>ニューラルネットワーク (2) ※1</li>\n<li>IoTとAI (2) ※1</li>\n</ul>\n</td>\n<td>\nデータサイエンス\nプログラム科目\n<ul>\n<li>多変量解析(2) ※1</li>\n<li>生体情報システム (2)</li>\n</ul>\n</td>\n<td>\nデータサイエンス\nプログラム科目\n<ul>\n<li>モデリングの数理(2)</li>\n<li>数値解析(2)</li>\n<li>AI・自然言語処理(2)</li>\n<li>AI・推薦システム (2)</li>\n</ul>\n</td>\n<td>\nデータサイエンス\nプログラム科目\n<ul>\n<li>AI・画像情報処理(2)</li>\n<li>質的データ分析(2)</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td>\n科目<br>演習\n</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>地域観光まちづくり論 (2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>※他学科専門科目</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>認知・感性とデータ分析 (2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>ソフトウェア工学(2)</li>\n<li>情報ネットワークと<br>セキュリティ (2)</li>\n<li>組み込みシステム (2)</li>\n<li>インターネットマーケティング(2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>生体情報分析(2)</li>\n<li>専門ゼミ1 (2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>専門ゼミ2 (2)</li>\n<li>フィンテック・ブロックチェーン(2)</li>\n<li>モバイルコンピューティング (2)</li>\n<li>金融データ解析(2)</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td>\n他プログラム<br>・他学科専門科目\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>データベース (2)</li>\n<li>感性情報処理(2)</li>\n<li>会計情報と経営(2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>品質管理とデータ分析 (2)</li>\n<li>医療情報システム (2)</li>\n</ul>\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n</td>\n<td>\n他プログラム<br>・他学科専門科目\n<ul>\n<li>保健医療と福祉(2)</li>\n<li>※他学科専門科目</li>\n</ul>\n</td>\n</tr>\n</table>\n赤:必修青:選択必修黒:選択():単位数\n※1 プログラム専門科目の必修扱い\n※2 実践英語3科目のうち2科目を選択必修\n</chunk>\n\n<chunk>\n履修モデル 情報エンジニアリングプログラム\n\n<table border="1">\n<tr>\n<th colspan="2">1年次(40単位)</th>\n<th colspan="2">2年次(42単位)</th>\n<th colspan="2">3年次(36単位)</th>\n<th>4年次(6単位)</th>\n</tr>\n<tr>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th>前期、①・②</th>\n<th>後期、③・④</th>\n<th></th>\n</tr>\n<tr>\n<td>\n総合科目\n<ul>\n<li>教養ゼミ (2)</li>\n<li>Python入門(2)</li>\n<li>教養スポーツ実習Ⅰ(1)</li>\n<li>コミュニケーション英語Ⅰ (1)</li>\n<li>キャリア形成活動Ⅰ (2) ※通年</li>\n<li>周南Well-being創生入門(2)</li>\n< ...
# Raw OCR Text for Page 8: '<chunk>
# 情報科学部情報科学科 履修モデル
# 履修モデル データサイエンスプログラム
#
# <table border="1">
# <tr>
# <th colspan="2">1年次(40単位)</th>
# <th colspan="2">2年次(42単位)</th>
# <th colspan="2">3年次(38単位)</th>
# <th>4年次(6単位)</th>
# </tr>
# <tr>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th></th>
# </tr>
# <tr>
# <td>
# 総合科目
# <ul>
# <li>教養ゼミ (2)</li>
# <li>Python入門(2)</li>
# <li>教養スポーツ実習Ⅰ (1)</li>
# <li>コミュニケーション英語Ⅰ (1)</li>
# <li>キャリア形成活動Ⅰ (2) ※通年</li>
# <li>周南Well-being創生入門(2)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>情報倫理(2)</li>
# <li>コミュニケーション英語ⅠⅡ (1)</li>
# <li>健康とスポーツ (2)</li>
# <li>人の健康生活 (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>周南Well-being創生論(2)</li>
# <li>情報社会論(2)</li>
# <li>コミュニケーション英語Ⅲ (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>コミュニケーション英語IV (1)</li>
# </ul>
# </td>
# <td>
# </td>
# <td>
# </td>
# <td rowspan="6" align="center">卒業研究(4)</td>
# </tr>
# <tr>
# <td>
# 学部基礎領域科目
# <ul>
# <li>情報科学概論(2)</li>
# <li>計算機概論(2)</li>
# <li>実社会とデータ分析(2)</li>
# <li>Python応用(2)</li>
# <li>データ分析基礎(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>地方創生とDX (2)</li>
# <li>VBAプログラミング (2)</li>
# <li>線形代数基礎(2)</li>
# <li>微分積分基礎(2)</li>
# <li>データの可視化(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>AI・機械学習基礎(2)</li>
# <li>確率統計基礎(2)</li>
# <li>Javaプログラミング (2)</li>
# <li>言語情報学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(AI) (2) ※2</li>
# <li>実践英語(数学) (2) ※2</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(情報) (2) ※2</li>
# <li>社会調査法(2)</li>
# <li>情報行動心理学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>コーパス言語学(2)</li>
# <li>AI、コンピュータと人間 (2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>データサイエンス概論 (2) ※1</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>ニューラルネットワーク (2) ※1</li>
# <li>IoTとAI (2) ※1</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>多変量解析(2) ※1</li>
# <li>生体情報システム (2)</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>モデリングの数理(2)</li>
# <li>数値解析(2)</li>
# <li>AI・自然言語処理(2)</li>
# <li>AI・推薦システム (2)</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>AI・画像情報処理(2)</li>
# <li>質的データ分析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 科目<br>演習
# </td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>地域観光まちづくり論 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>認知・感性とデータ分析 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>ソフトウェア工学(2)</li>
# <li>情報ネットワークと<br>セキュリティ (2)</li>
# <li>組み込みシステム (2)</li>
# <li>インターネットマーケティング(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報分析(2)</li>
# <li>専門ゼミ1 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>専門ゼミ2 (2)</li>
# <li>フィンテック・ブロックチェーン(2)</li>
# <li>モバイルコンピューティング (2)</li>
# <li>金融データ解析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>データベース (2)</li>
# <li>感性情報処理(2)</li>
# <li>会計情報と経営(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>品質管理とデータ分析 (2)</li>
# <li>医療情報システム (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>保健医療と福祉(2)</li>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# </tr>
# </table>
# 赤:必修青:選択必修黒:選択():単位数
# ※1 プログラム専門科目の必修扱い
# ※2 実践英語3科目のうち2科目を選択必修
# </chunk>
#
# <chunk>
# 履修モデル 情報エンジニアリングプログラム
#
# <table border="1">
# <tr>
# <th colspan="2">1年次(40単位)</th>
# <th colspan="2">2年次(42単位)</th>
# <th colspan="2">3年次(36単位)</th>
# <th>4年次(6単位)</th>
# </tr>
# <tr>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th></th>
# </tr>
# <tr>
# <td>
# 総合科目
# <ul>
# <li>教養ゼミ (2)</li>
# <li>Python入門(2)</li>
# <li>教養スポーツ実習Ⅰ(1)</li>
# <li>コミュニケーション英語Ⅰ (1)</li>
# <li>キャリア形成活動Ⅰ (2) ※通年</li>
# <li>周南Well-being創生入門(2)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>情報倫理(2)</li>
# <li>コミュニケーション英語ⅠⅡ (1)</li>
# <li>健康とスポーツ (2)</li>
# <li>人の健康生活 (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>周南Well-being創生論(2)</li>
# <li>情報社会論(2)</li>
# <li>コミュニケーション英語Ⅲ (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>コミュニケーション英語IV (1)</li>
# </ul>
# </td>
# <td>
# </td>
# <td>
# </td>
# <td rowspan="6" align="center">卒業研究(4)</td>
# </tr>
# <tr>
# <td>
# 学部基礎領域科目
# <ul>
# <li>情報科学概論(2)</li>
# <li>計算機概論(2)</li>
# <li>実社会とデータ分析 (2)</li>
# <li>Python応用(2)</li>
# <li>データ分析基礎(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>地方創生とDX (2)</li>
# <li>VBAプログラミング (2)</li>
# <li>線形代数基礎(2)</li>
# <li>微分積分基礎(2)</li>
# <li>データの可視化(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>AI・機械学習基礎(2)</li>
# <li>確率統計基礎(2)</li>
# <li>Javaプログラミング (2)</li>
# <li>言語情報学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(AI) (2) ※2</li>
# <li>実践英語(数学) (2) ※2</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(情報) (2) ※2</li>
# <li>社会調査法(2)</li>
# <li>情報行動心理学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>コーパス言語学(2)</li>
# <li>AI、コンピュータと人間 (2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>情報エンジニアリング概論 (2) <br>※1</li>
# </ul>
# </td>
# <td></td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>データベース (2) ※1</li>
# <li>アルゴリズムとデータ構造 (2) <br>※1</li>
# <li>プログラミング (2) ※1</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>ソフトウェア工学 (2)</li>
# <li>情報ネットワークと<br>セキュリティ (2)</li>
# <li>コンピュータグラフィックス(2)</li>
# <li>組み込みシステム (2)</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>ヒューマンコンピュータ<br>インタラクション (2)</li>
# <li>医療情報システム (2)</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>モバイルコンピューティング(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 科目<br>演習
# </td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>地域観光まちづくり論 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>認知・感性とデータ分析 (2)</li>
# <li>大規模・オープンデータ分析(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報システム (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報分析(2)</li>
# <li>専門ゼミ1 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>専門ゼミ2 (2)</li>
# <li>AI・画像情報処理(2)</li>
# <li>フィンテック・ブロックチェーン(2)</li>
# <li>金融データ解析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>ニューラルネットワーク (2)</li>
# <li>IoTとAI (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>AI・自然言語処理(2)</li>
# <li>AI・推薦システム (2)</li>
# <li>品質管理とデータ分析 (2)</li>
# <li>マーケティング・リサーチ (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>保健医療と福祉(2)</li>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# </tr>
# </table>
# </chunk>'
# Document Text for Page 8: '--- OCR Result for Page 8 ---
# <chunk>
# 情報科学部情報科学科 履修モデル
# 履修モデル データサイエンスプログラム
#
# <table border="1">
# <tr>
# <th colspan="2">1年次(40単位)</th>
# <th colspan="2">2年次(42単位)</th>
# <th colspan="2">3年次(38単位)</th>
# <th>4年次(6単位)</th>
# </tr>
# <tr>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th></th>
# </tr>
# <tr>
# <td>
# 総合科目
# <ul>
# <li>教養ゼミ (2)</li>
# <li>Python入門(2)</li>
# <li>教養スポーツ実習Ⅰ (1)</li>
# <li>コミュニケーション英語Ⅰ (1)</li>
# <li>キャリア形成活動Ⅰ (2) ※通年</li>
# <li>周南Well-being創生入門(2)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>情報倫理(2)</li>
# <li>コミュニケーション英語ⅠⅡ (1)</li>
# <li>健康とスポーツ (2)</li>
# <li>人の健康生活 (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>周南Well-being創生論(2)</li>
# <li>情報社会論(2)</li>
# <li>コミュニケーション英語Ⅲ (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>コミュニケーション英語IV (1)</li>
# </ul>
# </td>
# <td>
# </td>
# <td>
# </td>
# <td rowspan="6" align="center">卒業研究(4)</td>
# </tr>
# <tr>
# <td>
# 学部基礎領域科目
# <ul>
# <li>情報科学概論(2)</li>
# <li>計算機概論(2)</li>
# <li>実社会とデータ分析(2)</li>
# <li>Python応用(2)</li>
# <li>データ分析基礎(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>地方創生とDX (2)</li>
# <li>VBAプログラミング (2)</li>
# <li>線形代数基礎(2)</li>
# <li>微分積分基礎(2)</li>
# <li>データの可視化(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>AI・機械学習基礎(2)</li>
# <li>確率統計基礎(2)</li>
# <li>Javaプログラミング (2)</li>
# <li>言語情報学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(AI) (2) ※2</li>
# <li>実践英語(数学) (2) ※2</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(情報) (2) ※2</li>
# <li>社会調査法(2)</li>
# <li>情報行動心理学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>コーパス言語学(2)</li>
# <li>AI、コンピュータと人間 (2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>データサイエンス概論 (2) ※1</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>ニューラルネットワーク (2) ※1</li>
# <li>IoTとAI (2) ※1</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>多変量解析(2) ※1</li>
# <li>生体情報システム (2)</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>モデリングの数理(2)</li>
# <li>数値解析(2)</li>
# <li>AI・自然言語処理(2)</li>
# <li>AI・推薦システム (2)</li>
# </ul>
# </td>
# <td>
# データサイエンス
# プログラム科目
# <ul>
# <li>AI・画像情報処理(2)</li>
# <li>質的データ分析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 科目<br>演習
# </td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>地域観光まちづくり論 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>認知・感性とデータ分析 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>ソフトウェア工学(2)</li>
# <li>情報ネットワークと<br>セキュリティ (2)</li>
# <li>組み込みシステム (2)</li>
# <li>インターネットマーケティング(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報分析(2)</li>
# <li>専門ゼミ1 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>専門ゼミ2 (2)</li>
# <li>フィンテック・ブロックチェーン(2)</li>
# <li>モバイルコンピューティング (2)</li>
# <li>金融データ解析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>データベース (2)</li>
# <li>感性情報処理(2)</li>
# <li>会計情報と経営(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>品質管理とデータ分析 (2)</li>
# <li>医療情報システム (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>保健医療と福祉(2)</li>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# </tr>
# </table>
# 赤:必修青:選択必修黒:選択():単位数
# ※1 プログラム専門科目の必修扱い
# ※2 実践英語3科目のうち2科目を選択必修
# </chunk>
#
# <chunk>
# 履修モデル 情報エンジニアリングプログラム
#
# <table border="1">
# <tr>
# <th colspan="2">1年次(40単位)</th>
# <th colspan="2">2年次(42単位)</th>
# <th colspan="2">3年次(36単位)</th>
# <th>4年次(6単位)</th>
# </tr>
# <tr>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th>前期、①・②</th>
# <th>後期、③・④</th>
# <th></th>
# </tr>
# <tr>
# <td>
# 総合科目
# <ul>
# <li>教養ゼミ (2)</li>
# <li>Python入門(2)</li>
# <li>教養スポーツ実習Ⅰ(1)</li>
# <li>コミュニケーション英語Ⅰ (1)</li>
# <li>キャリア形成活動Ⅰ (2) ※通年</li>
# <li>周南Well-being創生入門(2)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>情報倫理(2)</li>
# <li>コミュニケーション英語ⅠⅡ (1)</li>
# <li>健康とスポーツ (2)</li>
# <li>人の健康生活 (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>周南Well-being創生論(2)</li>
# <li>情報社会論(2)</li>
# <li>コミュニケーション英語Ⅲ (1)</li>
# </ul>
# </td>
# <td>
# 総合科目
# <ul>
# <li>コミュニケーション英語IV (1)</li>
# </ul>
# </td>
# <td>
# </td>
# <td>
# </td>
# <td rowspan="6" align="center">卒業研究(4)</td>
# </tr>
# <tr>
# <td>
# 学部基礎領域科目
# <ul>
# <li>情報科学概論(2)</li>
# <li>計算機概論(2)</li>
# <li>実社会とデータ分析 (2)</li>
# <li>Python応用(2)</li>
# <li>データ分析基礎(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>地方創生とDX (2)</li>
# <li>VBAプログラミング (2)</li>
# <li>線形代数基礎(2)</li>
# <li>微分積分基礎(2)</li>
# <li>データの可視化(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>AI・機械学習基礎(2)</li>
# <li>確率統計基礎(2)</li>
# <li>Javaプログラミング (2)</li>
# <li>言語情報学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(AI) (2) ※2</li>
# <li>実践英語(数学) (2) ※2</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>実践英語(情報) (2) ※2</li>
# <li>社会調査法(2)</li>
# <li>情報行動心理学(2)</li>
# </ul>
# </td>
# <td>
# 学部基礎領域科目
# <ul>
# <li>コーパス言語学(2)</li>
# <li>AI、コンピュータと人間 (2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>情報エンジニアリング概論 (2) <br>※1</li>
# </ul>
# </td>
# <td></td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>データベース (2) ※1</li>
# <li>アルゴリズムとデータ構造 (2) <br>※1</li>
# <li>プログラミング (2) ※1</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>ソフトウェア工学 (2)</li>
# <li>情報ネットワークと<br>セキュリティ (2)</li>
# <li>コンピュータグラフィックス(2)</li>
# <li>組み込みシステム (2)</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>ヒューマンコンピュータ<br>インタラクション (2)</li>
# <li>医療情報システム (2)</li>
# </ul>
# </td>
# <td>
# 情報エンジニア
# リング<br>プログラム科目
# <ul>
# <li>モバイルコンピューティング(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 科目<br>演習
# </td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>地域観光まちづくり論 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>認知・感性とデータ分析 (2)</li>
# <li>大規模・オープンデータ分析(2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報システム (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>生体情報分析(2)</li>
# <li>専門ゼミ1 (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>専門ゼミ2 (2)</li>
# <li>AI・画像情報処理(2)</li>
# <li>フィンテック・ブロックチェーン(2)</li>
# <li>金融データ解析(2)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>ニューラルネットワーク (2)</li>
# <li>IoTとAI (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>AI・自然言語処理(2)</li>
# <li>AI・推薦システム (2)</li>
# <li>品質管理とデータ分析 (2)</li>
# <li>マーケティング・リサーチ (2)</li>
# </ul>
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# </td>
# <td>
# 他プログラム<br>・他学科専門科目
# <ul>
# <li>保健医療と福祉(2)</li>
# <li>※他学科専門科目</li>
# </ul>
# </td>
# </tr>
# </table>
# </chunk>'
# Processing Page 9
# ...
#   </tr>
#   <tr>
#     <td>体育</td>
#     <td>2</td>
#   </tr>
#   <tr>
#     <td>外国語コミュニケーション</td>
#     <td>2</td>
#   </tr>
#   <tr>
#     <td>数理、データ活用及び人工知能に関する科目又は情報機器の操作</td>
#     <td>2</td>
#   </tr>
# </table>
# </chunk>'
# Processing Page 15
# API Response for Page 15: candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='<chunk>\n# 4. 教育実習について\n## (1) 教育実習を履修するための注意\n教育実習は、取得する免許種によって、必要な時間数、対応する科目が異なります。\n\n<table>\n  <tr>\n    <th>免許状の種類</th>\n    <th>実習時間数</th>\n    <th>対応科目</th>\n  </tr>\n  <tr>\n    <td>高等学校教諭一種免許状</td>\n    <td>80時間以上(正味10日間以上)</td>\n    <td>教育実習I</td>\n  </tr>\n</table>\n\n## (2) 教育実習を履修するための条件\n教育実習が実施される前年度までに、すべての「教育の基礎的理解に関する科目等」に該当する科目を修得した学生にのみ履修資格を与えます。未修\n得の科目がある場合は、教育実習に行くことはできません。ただし、4年次開講科目については履修要件の対象外としますが、必ず履修登録を行ってく\nださい。\n</chunk>\n\n<chunk>\n# 5. 教職課程履修に関すること\n## (1) 履修者選抜\n本学の教職課程は、将来教職に就く意志のある学生を対象に開設しています。そのため、1年次後期に教職課程履修希望者を対象に、選考を行います。\n詳細は10月頃に公表します。\n*   原則として、1年次の修得単位が31単位未満(教職科目以外) 及び GPA が 2.7未満の者は対象から除かれます。\n*   1年次の教職科目「教師論」「教育課程論」のいずれか、もしくは両方の単位を修得しておく必要があります。\n\n## (2) 履修手続き\n教職課程履修者は、指定された期日までに誓約書の提出及び教職課程履修費を納入してください。一度納入された履修費は返金されません。手続きが\n完了しないと、教職科目の履修登録はできません。\n\n<table>\n  <tr>\n    <th></th>\n    <th></th>\n  </tr>\n  <tr>\n    <td>2年次</td>\n    <td>2万円</td>\n  </tr>\n  <tr>\n    <td>3年次</td>\n    <td>2万円</td>\n  </tr>\n</table>\n</chunk>\n\n<chunk>\n## (3) 履修辞退\n何らかの理由で教職課程の履修を辞退する場合は、学務課へ辞退届を提出してください。\n\n## (4) 教職課程授業科目\n教職課程授業科目表を確認し、必要な単位を修得してください。教職課程授業科目表の科目のうち、教育の基礎的理解に関する科目等、大学が独自に\n設定する科目は、各年次において履修できる単位数の上限を超えて履修することができます。また、教科及び教科の指導法に関する科目のうち以下の科\n目についても、各年次において履修できる単位数の上限を超えて履修することができます。履修できる単位数の上限を超えて履修した科目については、\n卒業要件の単位数に含まれません。\n\n<table>\n  <tr>\n    <th></th>\n  </tr>\n  <tr>\n    <td>3年次</td>\n  </tr>\n  <tr>\n    <td>情報社会と職業</td>\n  </tr>\n  <tr>\n    <td>情報科教育法I・II</td>\n  </tr>\n</table>\n</chunk>\n\n<chunk>\n# 6. 免許状の申請手続きについて\n免許状は、各都道府県の教育委員会が授与します。申請は各人で行ってもよいですが、本学では卒業予定者にかわって、免許状授与申請を一括して山\n口県教育委員会に提出し、卒業式のときに授与できるようにしています。そのための手続きについては、4年次後期にガイダンスを実施しますので、必\nず出席してください。\n</chunk>\n')], role='model'), citation_metadata=None, finish_message=None, token_count=None, finish_reason=<FinishReason.STOP: 'STOP'>, url_context_metadata=None, avg_logprobs=-0.015590056018716485, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=None)] create_time=None response_id=None model_version='gemini-2.0-flash' prompt_feedback=None usage_metadata=GenerateContentResponseUsageMetadata(cache_tokens_details=None, cached_content_token_count=None, candidates_token_count=845, candidates_tokens_details=[ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=845)], prompt_token_count=3440, prompt_tokens_details=[ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=86), ModalityTokenCount(modality=<MediaModality.IMAGE: 'IMAGE'>, token_count=3354)], thoughts_token_count=None, tool_use_prompt_token_count=None, tool_use_prompt_tokens_details=None, total_token_count=4285, traffic_type=None) automatic_function_calling_history=[] parsed=None
# Raw OCR Text for Page 15: '<chunk>
# # 4. 教育実習について
# ## (1) 教育実習を履修するための注意
# 教育実習は、取得する免許種によって、必要な時間数、対応する科目が異なります。
#
# <table>
#   <tr>
#     <th>免許状の種類</th>
#     <th>実習時間数</th>
#     <th>対応科目</th>
#   </tr>
#   <tr>
#     <td>高等学校教諭一種免許状</td>
#     <td>80時間以上(正味10日間以上)</td>
#     <td>教育実習I</td>
#   </tr>
# </table>
#
# ## (2) 教育実習を履修するための条件
# 教育実習が実施される前年度までに、すべての「教育の基礎的理解に関する科目等」に該当する科目を修得した学生にのみ履修資格を与えます。未修
# 得の科目がある場合は、教育実習に行くことはできません。ただし、4年次開講科目については履修要件の対象外としますが、必ず履修登録を行ってく
# ださい。
# </chunk>
#
# <chunk>
# # 5. 教職課程履修に関すること
# ## (1) 履修者選抜
# 本学の教職課程は、将来教職に就く意志のある学生を対象に開設しています。そのため、1年次後期に教職課程履修希望者を対象に、選考を行います。
# 詳細は10月頃に公表します。
# *   原則として、1年次の修得単位が31単位未満(教職科目以外) 及び GPA が 2.7未満の者は対象から除かれます。
# *   1年次の教職科目「教師論」「教育課程論」のいずれか、もしくは両方の単位を修得しておく必要があります。
#
# ## (2) 履修手続き
# 教職課程履修者は、指定された期日までに誓約書の提出及び教職課程履修費を納入してください。一度納入された履修費は返金されません。手続きが
# 完了しないと、教職科目の履修登録はできません。
#
# <table>
#   <tr>
#     <th></th>
#     <th></th>
#   </tr>
#   <tr>
#     <td>2年次</td>
#     <td>2万円</td>
#   </tr>
#   <tr>
#     <td>3年次</td>
#     <td>2万円</td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# ## (3) 履修辞退
# 何らかの理由で教職課程の履修を辞退する場合は、学務課へ辞退届を提出してください。
#
# ## (4) 教職課程授業科目
# 教職課程授業科目表を確認し、必要な単位を修得してください。教職課程授業科目表の科目のうち、教育の基礎的理解に関する科目等、大学が独自に
# 設定する科目は、各年次において履修できる単位数の上限を超えて履修することができます。また、教科及び教科の指導法に関する科目のうち以下の科
# 目についても、各年次において履修できる単位数の上限を超えて履修することができます。履修できる単位数の上限を超えて履修した科目については、
# 卒業要件の単位数に含まれません。
#
# <table>
#   <tr>
#     <th></th>
#   </tr>
#   <tr>
#     <td>3年次</td>
#   </tr>
#   <tr>
#     <td>情報社会と職業</td>
#   </tr>
#   <tr>
#     <td>情報科教育法I・II</td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# # 6. 免許状の申請手続きについて
# 免許状は、各都道府県の教育委員会が授与します。申請は各人で行ってもよいですが、本学では卒業予定者にかわって、免許状授与申請を一括して山
# 口県教育委員会に提出し、卒業式のときに授与できるようにしています。そのための手続きについては、4年次後期にガイダンスを実施しますので、必
# ず出席してください。
# </chunk>'
# Document Text for Page 15: '--- OCR Result for Page 15 ---
# <chunk>
# # 4. 教育実習について
# ## (1) 教育実習を履修するための注意
# 教育実習は、取得する免許種によって、必要な時間数、対応する科目が異なります。
#
# <table>
#   <tr>
#     <th>免許状の種類</th>
#     <th>実習時間数</th>
#     <th>対応科目</th>
#   </tr>
#   <tr>
#     <td>高等学校教諭一種免許状</td>
#     <td>80時間以上(正味10日間以上)</td>
#     <td>教育実習I</td>
#   </tr>
# </table>
#
# ## (2) 教育実習を履修するための条件
# 教育実習が実施される前年度までに、すべての「教育の基礎的理解に関する科目等」に該当する科目を修得した学生にのみ履修資格を与えます。未修
# 得の科目がある場合は、教育実習に行くことはできません。ただし、4年次開講科目については履修要件の対象外としますが、必ず履修登録を行ってく
# ださい。
# </chunk>
#
# <chunk>
# # 5. 教職課程履修に関すること
# ## (1) 履修者選抜
# 本学の教職課程は、将来教職に就く意志のある学生を対象に開設しています。そのため、1年次後期に教職課程履修希望者を対象に、選考を行います。
# 詳細は10月頃に公表します。
# *   原則として、1年次の修得単位が31単位未満(教職科目以外) 及び GPA が 2.7未満の者は対象から除かれます。
# *   1年次の教職科目「教師論」「教育課程論」のいずれか、もしくは両方の単位を修得しておく必要があります。
#
# ## (2) 履修手続き
# 教職課程履修者は、指定された期日までに誓約書の提出及び教職課程履修費を納入してください。一度納入された履修費は返金されません。手続きが
# 完了しないと、教職科目の履修登録はできません。
#
# <table>
#   <tr>
#     <th></th>
#     <th></th>
#   </tr>
#   <tr>
#     <td>2年次</td>
#     <td>2万円</td>
#   </tr>
#   <tr>
#     <td>3年次</td>
#     <td>2万円</td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# ## (3) 履修辞退
# 何らかの理由で教職課程の履修を辞退する場合は、学務課へ辞退届を提出してください。
#
# ## (4) 教職課程授業科目
# 教職課程授業科目表を確認し、必要な単位を修得してください。教職課程授業科目表の科目のうち、教育の基礎的理解に関する科目等、大学が独自に
# 設定する科目は、各年次において履修できる単位数の上限を超えて履修することができます。また、教科及び教科の指導法に関する科目のうち以下の科
# 目についても、各年次において履修できる単位数の上限を超えて履修することができます。履修できる単位数の上限を超えて履修した科目については、
# 卒業要件の単位数に含まれません。
#
# <table>
#   <tr>
#     <th></th>
#   </tr>
#   <tr>
#     <td>3年次</td>
#   </tr>
#   <tr>
#     <td>情報社会と職業</td>
#   </tr>
#   <tr>
#     <td>情報科教育法I・II</td>
#   </tr>
# </table>
# </chunk>
#
# <chunk>
# # 6. 免許状の申請手続きについて
# 免許状は、各都道府県の教育委員会が授与します。申請は各人で行ってもよいですが、本学では卒業予定者にかわって、免許状授与申請を一括して山
# 口県教育委員会に提出し、卒業式のときに授与できるようにしています。そのための手続きについては、4年次後期にガイダンスを実施しますので、必
# ず出席してください。
# </chunk>'
# Processing Page 16
# API Response for Page 16: candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, file_data=None, thought_signature=None, code_execution_result=None, executable_code=None, function_call=None, function_response=None, text='<chunk>\n教職課程授業科目表【高一種免(情報)】\n\n**■教育職員免許法施行規則第66条の6に定める科目**\n<table>\n  <tr>\n    <th>免許法施行規則に定める科目区分</th>\n    <th>1年次</th>\n    <th>2年次</th>\n    <th>3年次</th>\n    <th>4年次</th>\n  </tr>\n  <tr>\n    <td>日本国憲法</td>\n    <td>◎2 日本国憲法</td>\n    <td></td>\n    <td></td>\n    <td>◎…必修</td>\n  </tr>\n  <tr>\n    <td>体育</td>\n    <td>◎2 健康とスポーツ<br>◎1 教養スポーツ実習Ⅰ</td>\n    <td></td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>外国語コミュニケーション</td>\n    <td>◎1 コミュニケーション英語| <br>◎1 コミュニケーション英語 ||</td>\n    <td></td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>数理、データ活用及び人工知能に関する科目又は情報機器の操作</td>\n    <td>◎2 データサイエンス入門</td>\n    <td></td>\n    <td></td>\n    <td></td>\n  </tr>\n</table>\n\n</chunk>\n\n<chunk>\n**■教育の基礎的理解に関する科目等**\n<table>\n  <tr>\n    <th>免許法施行規則に定める科目区分</th>\n    <th>1年次</th>\n    <th>2年次</th>\n    <th>3年次</th>\n    <th>4年次</th>\n  </tr>\n  <tr>\n    <td>教育の基礎的理解に関する科目</td>\n    <td>◎2 教師論<br>◎2 教育課程論</td>\n    <td>◎2 教育原理<br>◎2 教育心理学<br>◎2 教育方法論I<br>2 教育方法論 II<br>◎2 生徒指導論<br>2 教育相談I<br>◎2 教育相談 II</td>\n    <td>◎2 教育行政論<br>◎2 特別支援教育<br>◎2 特別活動および総合的な学習の時間</td>\n    <td>◎…必修 無印･･･修得することが望ましい</td>\n  </tr>\n  <tr>\n    <td>道徳、総合的な学習の時間等の指導法及び生徒指導、教育相談等に関する科目</td>\n    <td></td>\n    <td></td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>教育実践に関する科目</td>\n    <td></td>\n    <td></td>\n    <td>◎2 教育実習基礎講座I</td>\n    <td>◎2 教育実習基礎講座 II<br>◎2 教育実習 I<br>◎2 教職実践演習</td>\n  </tr>\n</table>\n\n</chunk>\n\n<chunk>\n**■教科及び教科の指導法に関する科目**\n<table>\n  <tr>\n    <th>免許法施行規則に定める科目区分</th>\n    <th>1年次</th>\n    <th>2年次</th>\n    <th>3年次</th>\n    <th>4年次</th>\n  </tr>\n  <tr>\n    <td>情報社会(職業に関する内容を含む。)・情報倫理</td>\n    <td>◎2 情報倫理</td>\n    <td>◎2 情報社会論</td>\n    <td>◎2 情報社会と職業<br>2 ヒューマンコンピュータインタラクション</td>\n    <td>◎…必修</td>\n  </tr>\n  <tr>\n    <td>コンピュータ・情報処理</td>\n    <td>◎2 計算機概論<br>2 Python 入門</td>\n    <td>◎2 Java プログラミング<br>2 プログラミング</td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>情報システム</td>\n    <td></td>\n    <td>◎2 ソフトウェア工学<br>◎2 データベース</td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>情報通信ネットワーク</td>\n    <td></td>\n    <td>◎2 情報ネットワークとセキュリティ<br>2 ニューラルネットワーク</td>\n    <td></td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>マルチメディア表現・マルチメディア技術</td>\n    <td>2 データの可視化<br>2 VBA プログラミング<br>2 実社会とデータ分析</td>\n    <td>◎2 Web アプリケーション開発<br>2 生体情報システム</td>\n    <td>2 AI・画像情報処理</td>\n    <td></td>\n  </tr>\n  <tr>\n    <td>各教科の指導法(情報通信技術の活用を含む。)</td>\n    <td></td>\n    <td></td>\n    <td>◎2 情報科教育法I<br>◎2 情報科教育法II</td>\n    <td></td>\n  </tr>\n</table>\n※ 必修科目を除き8単位以上修得すること。\n\n</chunk>\n\n<chunk>\n**■大学が独自に設定する科目**\n<table>\n  <tr>\n    <th>免許法施行規則に定める科目区分</th>\n    <th>1年次</th>\n    <th>2年次</th>\n    <th>3年次</th>\n    <th>4年次</th>\n  </tr>\n  <tr>\n    <td>大学が独自に設定する科目</td>\n    <td></td>\n    <td>2 学校体験活動</td>\n    <td></td>\n    <td></td>\n  </tr>\n</table>\n</chunk>')], role='model'), citation_metadata=None, finish_message=None, token_count=None, finish_reason=<FinishReason.STOP: 'STOP'>, url_context_metadata=None, avg_logprobs=-0.015225273254286121, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=None)] create_time=None response_id=None model_version='gemini-2.0-flash' prompt_feedback=None usage_metadata=GenerateContentResponseUsageMetadata(cache_tokens_details=None, cached_content_token_count=None, candidates_token_count=1126, candidates_tokens_details=[ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=1126)], prompt_token_count=3440, prompt_tokens_details=[ModalityTokenCount(modality=<MediaModality.IMAGE: 'IMAGE'>, token_count=3354), ModalityTokenCount(modality=<MediaModality.TEXT: 'TEXT'>, token_count=86)], thoughts_token_count=None, tool_use_prompt_token_count=None, t ...
# Raw OCR Text for Page 16: '<chunk>
# 教職課程授業科目表【高一種免(情報)】
#
# **■教育職員免許法施行規則第66条の6に定める科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>日本国憲法</td>
#     <td>◎2 日本国憲法</td>
#     <td></td>
#     <td></td>
#     <td>◎…必修</td>
#   </tr>
#   <tr>
#     <td>体育</td>
#     <td>◎2 健康とスポーツ<br>◎1 教養スポーツ実習Ⅰ</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>外国語コミュニケーション</td>
#     <td>◎1 コミュニケーション英語| <br>◎1 コミュニケーション英語 ||</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>数理、データ活用及び人工知能に関する科目又は情報機器の操作</td>
#     <td>◎2 データサイエンス入門</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>
#
# </chunk>
#
# <chunk>
# **■教育の基礎的理解に関する科目等**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>教育の基礎的理解に関する科目</td>
#     <td>◎2 教師論<br>◎2 教育課程論</td>
#     <td>◎2 教育原理<br>◎2 教育心理学<br>◎2 教育方法論I<br>2 教育方法論 II<br>◎2 生徒指導論<br>2 教育相談I<br>◎2 教育相談 II</td>
#     <td>◎2 教育行政論<br>◎2 特別支援教育<br>◎2 特別活動および総合的な学習の時間</td>
#     <td>◎…必修 無印･･･修得することが望ましい</td>
#   </tr>
#   <tr>
#     <td>道徳、総合的な学習の時間等の指導法及び生徒指導、教育相談等に関する科目</td>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>教育実践に関する科目</td>
#     <td></td>
#     <td></td>
#     <td>◎2 教育実習基礎講座I</td>
#     <td>◎2 教育実習基礎講座 II<br>◎2 教育実習 I<br>◎2 教職実践演習</td>
#   </tr>
# </table>
#
# </chunk>
#
# <chunk>
# **■教科及び教科の指導法に関する科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>情報社会(職業に関する内容を含む。)・情報倫理</td>
#     <td>◎2 情報倫理</td>
#     <td>◎2 情報社会論</td>
#     <td>◎2 情報社会と職業<br>2 ヒューマンコンピュータインタラクション</td>
#     <td>◎…必修</td>
#   </tr>
#   <tr>
#     <td>コンピュータ・情報処理</td>
#     <td>◎2 計算機概論<br>2 Python 入門</td>
#     <td>◎2 Java プログラミング<br>2 プログラミング</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>情報システム</td>
#     <td></td>
#     <td>◎2 ソフトウェア工学<br>◎2 データベース</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>情報通信ネットワーク</td>
#     <td></td>
#     <td>◎2 情報ネットワークとセキュリティ<br>2 ニューラルネットワーク</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>マルチメディア表現・マルチメディア技術</td>
#     <td>2 データの可視化<br>2 VBA プログラミング<br>2 実社会とデータ分析</td>
#     <td>◎2 Web アプリケーション開発<br>2 生体情報システム</td>
#     <td>2 AI・画像情報処理</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>各教科の指導法(情報通信技術の活用を含む。)</td>
#     <td></td>
#     <td></td>
#     <td>◎2 情報科教育法I<br>◎2 情報科教育法II</td>
#     <td></td>
#   </tr>
# </table>
# ※ 必修科目を除き8単位以上修得すること。
#
# </chunk>
#
# <chunk>
# **■大学が独自に設定する科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>大学が独自に設定する科目</td>
#     <td></td>
#     <td>2 学校体験活動</td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>
# </chunk>'
# Document Text for Page 16: '--- OCR Result for Page 16 ---
# <chunk>
# 教職課程授業科目表【高一種免(情報)】
#
# **■教育職員免許法施行規則第66条の6に定める科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>日本国憲法</td>
#     <td>◎2 日本国憲法</td>
#     <td></td>
#     <td></td>
#     <td>◎…必修</td>
#   </tr>
#   <tr>
#     <td>体育</td>
#     <td>◎2 健康とスポーツ<br>◎1 教養スポーツ実習Ⅰ</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>外国語コミュニケーション</td>
#     <td>◎1 コミュニケーション英語| <br>◎1 コミュニケーション英語 ||</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>数理、データ活用及び人工知能に関する科目又は情報機器の操作</td>
#     <td>◎2 データサイエンス入門</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>
#
# </chunk>
#
# <chunk>
# **■教育の基礎的理解に関する科目等**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>教育の基礎的理解に関する科目</td>
#     <td>◎2 教師論<br>◎2 教育課程論</td>
#     <td>◎2 教育原理<br>◎2 教育心理学<br>◎2 教育方法論I<br>2 教育方法論 II<br>◎2 生徒指導論<br>2 教育相談I<br>◎2 教育相談 II</td>
#     <td>◎2 教育行政論<br>◎2 特別支援教育<br>◎2 特別活動および総合的な学習の時間</td>
#     <td>◎…必修 無印･･･修得することが望ましい</td>
#   </tr>
#   <tr>
#     <td>道徳、総合的な学習の時間等の指導法及び生徒指導、教育相談等に関する科目</td>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>教育実践に関する科目</td>
#     <td></td>
#     <td></td>
#     <td>◎2 教育実習基礎講座I</td>
#     <td>◎2 教育実習基礎講座 II<br>◎2 教育実習 I<br>◎2 教職実践演習</td>
#   </tr>
# </table>
#
# </chunk>
#
# <chunk>
# **■教科及び教科の指導法に関する科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>情報社会(職業に関する内容を含む。)・情報倫理</td>
#     <td>◎2 情報倫理</td>
#     <td>◎2 情報社会論</td>
#     <td>◎2 情報社会と職業<br>2 ヒューマンコンピュータインタラクション</td>
#     <td>◎…必修</td>
#   </tr>
#   <tr>
#     <td>コンピュータ・情報処理</td>
#     <td>◎2 計算機概論<br>2 Python 入門</td>
#     <td>◎2 Java プログラミング<br>2 プログラミング</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>情報システム</td>
#     <td></td>
#     <td>◎2 ソフトウェア工学<br>◎2 データベース</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>情報通信ネットワーク</td>
#     <td></td>
#     <td>◎2 情報ネットワークとセキュリティ<br>2 ニューラルネットワーク</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>マルチメディア表現・マルチメディア技術</td>
#     <td>2 データの可視化<br>2 VBA プログラミング<br>2 実社会とデータ分析</td>
#     <td>◎2 Web アプリケーション開発<br>2 生体情報システム</td>
#     <td>2 AI・画像情報処理</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>各教科の指導法(情報通信技術の活用を含む。)</td>
#     <td></td>
#     <td></td>
#     <td>◎2 情報科教育法I<br>◎2 情報科教育法II</td>
#     <td></td>
#   </tr>
# </table>
# ※ 必修科目を除き8単位以上修得すること。
#
# </chunk>
#
# <chunk>
# **■大学が独自に設定する科目**
# <table>
#   <tr>
#     <th>免許法施行規則に定める科目区分</th>
#     <th>1年次</th>
#     <th>2年次</th>
#     <th>3年次</th>
#     <th>4年次</th>
#   </tr>
#   <tr>
#     <td>大学が独自に設定する科目</td>
#     <td></td>
#     <td>2 学校体験活動</td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>
# </chunk>'

# %%
langchain_docs = [LangChainDocument(page_content=doc.text, metadata=doc.metadata) for doc in documents]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 256,
    chunk_overlap=20,
    length_function=len,
    add_start_index=True
)

docs = text_splitter.split_documents(langchain_docs)

# %%
llama_docs = [LlamaDocument.from_langchain_format(d) for d in docs]

Settings.llm = my_llm
Settings.embed_model = embedding_model
index = VectorStoreIndex.from_documents(llama_docs, show_progress=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/llama_index/core/indices/base.py:113: DeprecationWarning: Call to deprecated method get_doc_id. ('get_doc_id' is deprecated, access the 'id_' property instead.) -- Deprecated since version 0.12.2.
#   docstore.set_document_hash(doc.get_doc_id(), doc.hash)
# Parsing nodes:   0%|          | 0/396 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/396 [00:00<?, ?it/s]

# %%
tokenizer.pad_token_id = tokenizer.eos_token_id
generation_config = model.generation_config
generation_config.pad_token_id = tokenizer.eos_token_id

# %%
query = """
情報科学部の特色を教えてください。
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 情報科学部の特色は、実学を重視したカリキュラムを通して、情報技術を基盤にした問題解決能力を養う点です。特に、データサイエ
# ンスや人工知能、IoT、Cybersecurityなどの分野に力を入れており、実践的なスキルを身に付けることができます。
# さらに、企業との協同研究やインターンシップなどの機会を提供し、学生が即戦力として社会に貢献できる人材を育成することを目指
# しています。(p4)

# %%
query = """
情報科学部はセメスター制とクオーター制の授業、どちらが多く実施されていますか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 情報科学部で開講される専門科目の多くはクオーター制で実施されています。

# %%
query = """
情報科学部は1年を通じてセメスター制の授業の方が、クオーター制の授業より多く実施されていますか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 情報科学部では、セメスター制で開講される科目とクオーター制で開講される科目が混在しています。したがって、セメスター制の授
# 業がクオーター制の授業より多く実施されているとは一概に言えません。

# %%
query = """
AIに関して学びたいのですが、情報科学部の3つのプログラムのうちどのプログラムが最適でしょうか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# AIを学ぶには、データサイエンスプログラムが最適です。データサイエンスプログラムは、データ分析や機械学習を通して、AIの
# 基礎を学ぶことができます。根拠は、情報科学部のプログラム紹介(p7)です。

# %%
query = """
大規模なデータを分析してみたいのですが、それを学ぶには情報科学部の3つのプログラムのうちどのプログラムが最適でしょうか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# データサイエンス・プログラムが最適です。データサイエンス・プログラムでは、大量のデータをどのように分析・活用するかを学ぶ
# ことができます。

# %%
query = """
金融分野の動向をデータ分析を通じて研究したいのですが、情報科学科の3つのプログラムのうちどのプログラムが最適でしょうか？
"""
print("回答を生成しています。少々お待ちください。")
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 回答を生成しています。少々お待ちください。
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 情報科学科には「情報科学コース」「データサイエンスコース」「情報システムコース」がありますが、金融分野の動向をデータ分析
# を通じて研究するには「データサイエンスコース」が最適です。データサイエンスコースでは、統計学や機械学習を用いてデータ分析
# を行うことができます。金融分野の研究では、時系列データや大量のデータを分析する必要があり、データサイエンスコースのカリキ
# ュラムは非常に有効です。(p5)

# %%
query = """
4年次において、卒業論文の提出締め切りはいつ頃ですか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 周南公立大学の情報科学部情報科学科の卒業論文の提出締め切りは、4年次の「卒業論文中間発表会」後です。具体的には、例年12
# 月上旬に開催される「卒業論文中間発表会」が終了した後、指導教員と相談の上、個別に設定されます。詳細な日程は、指導教員や学
# 科事務室に確認する必要があります。

# %%
query = """
情報科学部で取得できる教職課程の免許状は何ですか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 情報科学部では、情報科の教職課程の免許状が取得可能です。

# %%
query = """
周南公立大学は日本のどこに位置しますか？
"""
response = query_engine(query, index, my_llm)
final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
wrapped_answer = textwrap.fill(final_answer, width=60)
print(wrapped_answer)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 周南公立大学は、山口県下松市に位置します。

# %%
def answer_question(query):
  print("回答を生成しています。少々お待ちください。")
  response = query_engine(query, index, my_llm)
  final_answer = response.generations[0][0].text.split("【最終回答】:")[-1].strip()
  wrapped_answer = textwrap.fill(final_answer, width=60)
  return wrapped_answer

# %%
user_q = input("質問を入力してください: ")

print(answer_question(user_q))
# Out:
# 質問を入力してください: 卒業要件にGPAは関係ありますか？
# 回答を生成しています。少々お待ちください。
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 周南公立大学の卒業要件には、GPAは関係します。具体的には、卒業要件の条件に「GPAが2.5以上であること」が明記されて
# います。(p15)。したがって、学生はこの条件を満たす必要があります。
